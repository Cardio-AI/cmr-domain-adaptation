# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root 
change_wd_to_project_root()
#from pyforest import *
from src.utils.Notebook_imports import *
from src.utils.Metrics_acdc import compute_metrics_on_files, compute_metrics_on_directories
from src.visualization.Visualize import bland_altman_metric_plot, create_eval_plot
Console_and_file_logger('Change spacing', logging.INFO)
import matplotlib.pyplot as plt
# jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/3d-mri-domain-adaption
# 2020-10-22 12:29:25,347 INFO -------------------- Start --------------------
# 2020-10-22 12:29:25,361 INFO Working directory: /mnt/ssd/git/3d-mri-domain-adaption.
# 2020-10-22 12:29:25,362 INFO Log file: ./logs/Change spacing.log
# 2020-10-22 12:29:25,362 INFO Log level for console: INFO

# %%
# select folder with the images and masks
# choose the root folder before the gt/pred sub-folders
from ipyfilechooser import FileChooser
path_chooser = FileChooser(os.path.join(os.getcwd(),'data/predicted/'), '')
display(path_chooser)
# Out:
# FileChooser(path='/mnt/ssd/git/3d-mri-domain-adaption/data/predicted', filename='', title='HTML(value='', layo…

# %%
from src.data.Dataset import copy_meta_and_save
from src. data.Preprocess import resample_3D

root_path = path_chooser.selected
current_spacing = (1.5,1.5,1.5)

ax_spacing = (1.3,1.3,6.0)
ax_size = (258,258,32)

gt_path = os.path.join(root_path, 'gt')
#gt_path = 'data/temp/gt'
gt = sorted(glob.glob(os.path.join(gt_path, '*')))
logging.info('GT files: {}'.format(len(gt)))
logging.info(gt[:5])

pred_path = os.path.join(root_path, 'pred')
#pred_path = 'data/temp/pred'
pred = sorted(glob.glob(os.path.join(pred_path, '*')))
logging.info('Pred files: {}'.format(len(pred)))
logging.info(pred[:5])

# proof if we have one gt file for each prediction and vize versa
"""p = set(os.path.basename(elem) for elem in pred)
g = set(os.path.basename(elem) for elem in gt)
logging.info(g-p)
logging.info(p-g)
logging.info(len(p.intersection(g)))"""

gt_sitk = [sitk.ReadImage(g) for g in gt]
pred_sitk = [sitk.ReadImage(p) for p in pred]

[g.SetSpacing(current_spacing) for g in gt_sitk]
[p.SetSpacing(current_spacing) for p in pred_sitk]

gt_sitk = [resample_3D(g, size=ax_size, spacing=ax_spacing) for g in gt_sitk]
pred_sitk = [resample_3D(p, size=ax_size, spacing=ax_spacing) for p in pred_sitk]

new_gt = [g.replace('3D','orig_spacing') for g in gt]
new_pred = [p.replace('3D','orig_spacing') for p in pred]

[sitk.WriteImage(g, g_path) for g, g_path in zip(gt_sitk, new_gt)]
[sitk.WriteImage(g, g_path) for g, g_path in zip(pred_sitk, new_pred)]




#compute_metrics_on_directories(gt_path, pred_path, results_path=os.path.join(root_path,'results.csv'))
# Out:
# 2020-10-22 12:32:53,207 INFO GT files: 160
# 2020-10-22 12:32:53,208 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/gt/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/gt/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/gt/0000-0PTV75MP_2005-06-27_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/gt/0000-0PTV75MP_2005-06-27_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/gt/0000-0RPELLU8_2007-02-13_ED_msk.nrrd']
# 2020-10-22 12:32:53,209 INFO Pred files: 160
# 2020-10-22 12:32:53,209 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/pred/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/pred/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/pred/0000-0PTV75MP_2005-06-27_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/pred/0000-0PTV75MP_2005-06-27_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/paper_baseline_1ax_1sax_01focus_inplane/3D/pred/0000-0RPELLU8_2007-02-13_ED_msk.nrrd']
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
@interact
def load_evaluation(eval_path = sorted(glob.glob('data/predicted/**/**/*.csv'))):
    print(eval_path)
    import pandas as pd
    global eval, df_dice, df_hd, df_vol
    eval = pd.read_csv(eval_path)
    print(eval.columns)
    # df need to be melt down = every row represented by one value
    # first define melting/categorical columns, second define all values
    
    try:
        df_hd = pd.melt(eval, ['Name'], ['Hausdorff LV', 'Hausdorff RV', 'Hausdorff MYO'])
    except Exception as e:
        print('no hausdorff given')
    df_dice = pd.melt(eval, ['Name'], ['Dice LV', 'Dice RV', 'Dice MYO'])
    df_diff = pd.melt(eval, ['Name'], ['Err LV(ml)', 'Err RV(ml)', 'Err MYO(ml)'])
    df_vol = pd.melt(eval, ['Name'], ['Volume LV', 'Volume RV', 'Volume MYO'])
    create_eval_plot(df_dice, df_hd, df_diff, df_vol, eval)
    return(eval.head())
# Out:
# interactive(children=(Dropdown(description='eval_path', options=('data/predicted/1_ax_1_sax_1_unet_NoPost/3D/r…

# %%
# create a scatterplot
# nobs = mean
import seaborn as sns
#plt.rcParams['font.fontname'] = "Cambria"
outliers = False

plt.rcParams.update({'font.size': 20})
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,5), sharey=False)
my_pal_1 = {"Dice LV": "dodgerblue", "Dice MYO": "g", "Dice RV":"darkorange"}
my_pal_2 = {"Err LV(ml)": "dodgerblue", "Err MYO(ml)": "g", "Err RV(ml)":"darkorange"}
my_pal_3 = {"Volume LV": "dodgerblue", "Volume MYO": "g", "Volume RV":"darkorange"}

ax1 = sns.stripplot(x= 'variable',y = 'value', data=df_dice,order=["Dice LV", "Dice MYO", "Dice RV"],palette=my_pal_1 , ax=ax1)
medians = df_dice.groupby(['variable'])['value'].mean().round(2)
sd = df_dice.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]

for tick,label in zip(range(len(ax1.get_xticklabels())),ax1.get_xticklabels()):
    _ = ax1.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax1, ylim=(0,1))
plt.setp(ax1, ylabel=('DICE'))
plt.setp(ax1, xlabel='')
ax1.set_xticklabels(['LV','MYO', 'RV'])

ax2 = sns.stripplot(x= 'variable',y = 'value', data=df_hd,order=["Err LV(ml)", "Err MYO(ml)", "Err RV(ml)"],palette=my_pal_2 , ax=ax2)
medians = df_hd.groupby(['variable'])['value'].mean().round(2)
sd = df_hd.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]

for tick,label in zip(range(len(ax2.get_xticklabels())),ax2.get_xticklabels()):
    _ = ax2.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax2, ylim=(-650,650))
plt.setp(ax2, ylabel=('Err (pred - gt)\n vol in ml'))
plt.setp(ax2, xlabel='')
ax2.set_xticklabels(['LV','MYO', 'RV'])
    
ax3 = sns.stripplot(x= 'variable',y = 'value',order=["Volume LV", "Volume MYO", "Volume RV"],palette=my_pal_3 , data=df_vol, ax=ax3)
medians = df_vol.groupby(['variable'])['value'].mean().round(2)
sd = df_vol.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]

for tick,label in zip(range(len(ax3.get_xticklabels())),ax3.get_xticklabels()):
    _ = ax3.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax3, ylim=(0,2500))
plt.setp(ax3, ylabel=('Vol size\n in ml'))
plt.setp(ax3, xlabel='')
ax3.set_xticklabels(['LV','MYO', 'RV'])
plt.tight_layout()

# %%
# create a violinplot
# nobs = median
import seaborn as sns
outliers = False


plt.rcParams.update({'font.size': 20})
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,5), sharey=False)

ax1 = sns.violinplot(x= 'variable',y = 'value', data=df_dice,order=["Dice LV", "Dice MYO", "Dice RV"], palette=my_pal_1 , showfliers = outliers, ax=ax1)
medians = df_dice.groupby(['variable'])['value'].median().round(2)
sd = df_dice.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]

for tick,label in zip(range(len(ax1.get_xticklabels())),ax1.get_xticklabels()):
    _ = ax1.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax1, ylim=(0,1))
plt.setp(ax1, ylabel=('DICE'))
plt.setp(ax1, xlabel='')
ax1.set_xticklabels(['LV','MYO', 'RV'])

ax2 = sns.violinplot(x= 'variable',y = 'value', data=df_hd,order=["Err LV(ml)", "Err MYO(ml)", "Err RV(ml)"],palette=my_pal_2 , showfliers = outliers, ax=ax2)
medians = df_hd.groupby(['variable'])['value'].median().round(2)
sd = df_hd.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]

for tick,label in zip(range(len(ax2.get_xticklabels())),ax2.get_xticklabels()):
    _ = ax2.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax2, ylim=(-650,650))
plt.setp(ax2, ylabel=('Err (pred - gt) \nvol in ml'))
plt.setp(ax2, xlabel='')
ax2.set_xticklabels(['LV','MYO', 'RV'])
    
ax3 = sns.violinplot(x= 'variable',y = 'value',order=["Volume LV", "Volume MYO", "Volume RV"],palette=my_pal_3 , showfliers = outliers, data=df_vol, ax=ax3)

medians = df_vol.groupby(['variable'])['value'].median().round(2)
sd = df_vol.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]


for tick,label in zip(range(len(ax3.get_xticklabels())),ax3.get_xticklabels()):
    _ = ax3.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax3, ylim=(0,2500))
plt.setp(ax3, ylabel=('Vol size in ml'))
plt.setp(ax3, xlabel='')
ax3.set_xticklabels(['LV','MYO', 'RV'])
plt.tight_layout()

# %%
# create a violinplot with an integrated bland altmann plot
# nobs = median
import seaborn as sns
outliers = False
my_pal_1 = {"Dice LV": "dodgerblue", "Dice MYO": "g", "Dice RV":"darkorange"}
my_pal_2 = {"Err LV(ml)": "dodgerblue", "Err MYO(ml)": "g", "Err RV(ml)":"darkorange"}
my_pal_3 = {"Volume LV": "dodgerblue", "Volume MYO": "g", "Volume RV":"darkorange"}


plt.rcParams.update({'font.size': 20})
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(25,8), sharey=False)

ax1 = sns.violinplot(x= 'variable',y = 'value', data=df_dice,order=["Dice LV", "Dice MYO", "Dice RV"],palette=my_pal_1 , showfliers = outliers, ax=ax1)
medians = df_dice.groupby(['variable'])['value'].median().round(2)
sd = df_dice.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]

for tick,label in zip(range(len(ax1.get_xticklabels())),ax1.get_xticklabels()):
    _ = ax1.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax1, ylim=(0,1))
plt.setp(ax1, ylabel=('DICE'))
plt.setp(ax1, xlabel='')
ax1.set_xticklabels(['LV','MYO', 'RV'])

ax2 = bland_altman_metric_plot(eval, ax2)

ax3 = sns.violinplot(x= 'variable',y = 'value',order=["Volume LV", "Volume MYO", "Volume RV"], palette=my_pal_3, showfliers = outliers, data=df_vol, ax=ax3)

medians = df_vol.groupby(['variable'])['value'].median().round(2)
sd = df_vol.groupby(['variable'])['value'].std().round(2)
nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]


for tick,label in zip(range(len(ax3.get_xticklabels())),ax3.get_xticklabels()):
    _ = ax3.text(tick, medians[tick], nobs[tick],horizontalalignment='center', size='x-small', color='black', weight='semibold')
plt.setp(ax3, ylim=(0,2500))
plt.setp(ax3, ylabel=('Vol size in ml'))
plt.setp(ax3, xlabel='')
ax3.set_xticklabels(['LV','MYO', 'RV'])
plt.tight_layout()

# %%
def calc_mean_scores(df):
    
    df_dice = pd.melt(df, ['Name'], ['Dice LV', 'Dice RV', 'Dice MYO'])
    df_hd = pd.melt(df, ['Name'], ['Err LV(ml)', 'Err RV(ml)', 'Err MYO(ml)'])
    df_vol = pd.melt(df, ['Name'], ['Volume LV', 'Volume RV', 'Volume MYO'])
    
    d_mean = df['Dice LV', 'Dice RV', 'Dice MYO'].mean()
    d_median = df['Dice LV', 'Dice RV', 'Dice MYO'].median()
    d_sd = df['Dice LV', 'Dice RV', 'Dice MYO'].sd()
    df = pd.DataFrame()
    
    df.extend(medians_dice = df_dice.groupby(['variable'])['value'].median().round(2))
    mean_dice = df_dice.groupby(['variable'])['value'].mean().round(2)
    sd_dice = df_dice.groupby(['variable'])['value'].std().round(2)
    
    medians_hd = df_dice.groupby(['variable'])['value'].median().round(2)
    sd_hd = df_dice.groupby(['variable'])['value'].std().round(2)
    
    medians_vol = df_dice.groupby(['variable'])['value'].median().round(2)
    sd_vol = df_dice.groupby(['variable'])['value'].std().round(2)
    
    return d_mean, d_median, d_sd

# %%
cols = ['dice LV median','dice RV median','dice MYO median', 'dice LV mean', 'dice RV mean','dice MYO mean', 'dice LV sd', 'dice RV sd', 'dice MYO sd']
scores = []

scores.extend(df_dice.groupby(['variable'])['value'].median().round(2).values)
scores.extend(df_dice.groupby(['variable'])['value'].mean().round(2).values)
scores.extend(df_dice.groupby(['variable'])['value'].std().round(2).values)

df = pd.DataFrame(columns=cols)
df.append(scores)
df
# Out:
# Empty DataFrame
# Columns: [dice LV median, dice RV median, dice MYO median, dice LV mean, dice RV mean, dice MYO mean, dice LV sd, dice RV sd, dice MYO sd]
# Index: []

# %%
eval.head()
# Out:
#                               Name   Dice LV   Volume LV  Err LV(ml)  \
# 0  0000-0HQQW4ZN_2007-05-23_ED_msk  0.790685   88.313625  -30.324375
# 1  0000-0HQQW4ZN_2007-05-23_ES_msk  0.830249   41.478750    2.176875
# 2  0000-2CVUG1C5_2006-09-06_ED_msk  0.827723  105.691500   11.677500
# 3  0000-2CVUG1C5_2006-09-06_ES_msk  0.732182   30.300750   -1.765125
# 4  0000-2CW0G1A5_2006-04-06_ED_msk  0.856794  140.487750  -39.399750
#
#    Hausdorff LV   Dice RV  Volume RV  Err RV(ml)  Hausdorff RV  Dice MYO  \
# 0     17.146428  0.841041  141.89175  -35.650125     11.357817  0.518385
# 1      7.071068  0.805932   79.90650   -6.773625     13.341664  0.663478
# 2     13.747727  0.830228  193.67100  -49.075875     18.466185  0.590159
# 3     19.949937  0.671528   83.32200  -74.013750     13.453624  0.497653
# 4     12.328828  0.891899  226.42875  -44.178750      9.055385  0.629127
#
#    Volume MYO  Err MYO(ml)  Hausdorff MYO
# 0   53.770500    -2.878875      22.315914
# 1   51.067125     2.656125      12.083046
# 2   91.459125     5.406750      18.466185
# 3   54.789750   -19.831500      23.895606
# 4   82.947375    -5.224500      20.832667

# %%
def get_dice(exp):
    df = pd.read_csv(exp)
    d_lv = df['Dice LV']
    d_rv = df['Dice RV']
    d_myo = df['Dice MYO']
    
    
    hd_lv = df['Hausdorff LV']
    hd_rv = df['Hausdorff RV']
    hd_myo = df['Hausdorff MYO']
    
    res = {'experiment':exp, 
           'dice lv mean':d_lv.mean(), 'dice lv sd':d_lv.std(),'HD lv mean':hd_lv.mean(), 'HD lv sd':hd_lv.std(),
           'dice lv median':d_lv.median(),'HD lv median':hd_lv.median(),
           
           'dice rv mean':d_rv.mean(), 'dice rv sd':d_rv.std(),'HD rv mean':hd_rv.mean(), 'HD rv sd':hd_rv.std(),
           'dice rv median':d_rv.median(),'HD rv median':hd_rv.median(),
           
           'dice myo mean':d_myo.mean(), 'dice myo sd':d_myo.std(),'HD myo mean':hd_myo.mean(), 'HD myo sd':hd_myo.std(),
           'dice myo median':d_myo.median(),'HD myo median':hd_myo.median()
          }
    return [res]

# %% [markdown]
# # Load one experiment evaluation, calc mean, std and median and merge into one dataframe

# %%
import pandas as pd
df_scores = pd.DataFrame(columns=['experiment'])
@interact_manual
def load_evaluation(eval_path = sorted(glob.glob('data/predicted/**/**/*.csv'))):
    global df_scores
    print(eval_path)
    import pandas as pd
    
    res = get_dice(eval_path)
    # make sure every experiment is only once in the overview
    if res[0]['experiment'] not in df_scores['experiment'].values:
        df_scores = df_scores.append(res)

    return df_scores.round(2)
# Out:
# interactive(children=(Dropdown(description='eval_path', options=('data/predicted/1_ax_1_sax_1_unet_NoPost/3D/r…

# %%
df_scores.to_latex(index=False)
# Out:
# '\\begin{tabular}{lrrrrrrrrrrrrrrrrrr}\n\\toprule\n                                        experiment &  dice lv mean &  dice lv sd &  HD lv mean &  HD lv sd &  dice lv median &  HD lv median &  dice rv mean &  dice rv sd &  HD rv mean &  HD rv sd &  dice rv median &  HD rv median &  dice myo mean &  dice myo sd &  HD myo mean &  HD myo sd &  dice myo median &  HD myo median \\\\\n\\midrule\n    data/predicted/gcn\\_excl\\_ax\\_acdc/3D/results.csv &      0.933592 &    0.039717 &    5.375432 &  4.331274 &        0.948581 &      3.870829 &      0.853313 &    0.087360 &   12.790751 &  5.893329 &        0.873111 &     11.291394 &       0.866517 &     0.030107 &     6.584902 &   4.225659 &         0.867752 &       4.785578 \\\\\n     data/predicted/gcn\\_excl\\_ax\\_gcn/3D/results.csv &      0.925004 &    0.033177 &    6.243185 &  5.912112 &        0.933258 &      5.099020 &      0.896032 &    0.044410 &   11.326376 &  7.199367 &        0.909364 &      9.486833 &       0.809845 &     0.043288 &     9.379612 &   4.850893 &         0.818460 &       8.366600 \\\\\n    data/predicted/gcn\\_excl\\_ax\\_onAX/3D/results.csv &      0.781469 &    0.168853 &   15.237115 &  9.845865 &        0.832408 &     11.554200 &      0.524859 &    0.191400 &   33.979336 &  8.295236 &        0.555602 &     33.316662 &       0.634674 &     0.137665 &    19.946922 &   8.632055 &         0.666538 &      17.029386 \\\\\n data/predicted/gcn\\_excl\\_ax\\_onAX2SAX/3D/results... &      0.820580 &    0.139836 &   11.701018 &  6.994213 &        0.855915 &      9.460407 &      0.752791 &    0.149082 &   17.867722 &  6.765648 &        0.793927 &     16.340106 &       0.613785 &     0.134200 &    17.017136 &   7.547187 &         0.647906 &      14.543029 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
df_scores.to_csv('reports/tmi_results_table_1.csv',index=False)
df_scores.to_excel('reports/tmi_results_table_1.xls',index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-79-0696baebfae3> in <module>
#       1 df_scores.to_csv('reports/tmi_results_table_1.csv',index=False)
# ----> 2 df_scores.to_excel('reports/tmi_results_table_1.xls',index=False)
#
# ~/anaconda3/envs/ax2sax/lib/python3.6/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2027             startcol=startcol,
#    2028             freeze_panes=freeze_panes,
# -> 2029             engine=engine,
#    2030         )
#    2031
#
# ~/anaconda3/envs/ax2sax/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# --> 730             writer = ExcelWriter(stringify_path(writer), engine=engine)
#     731             need_save = True
#     732
#
# ~/anaconda3/envs/ax2sax/lib/python3.6/site-packages/pandas/io/excel/_xlwt.py in __init__(self, path, engine, encoding, mode, **engine_kwargs)
#      11     def __init__(self, path, engine=None, encoding=None, mode="w", **engine_kwargs):
#      12         # Use the xlwt module as the Excel writer.
# ---> 13         import xlwt
#      14
#      15         engine_kwargs["engine"] = engine
#
# ModuleNotFoundError: No module named 'xlwt'

# %% [markdown]
# # Calculate scores for a list of folders in predicted

# %%
parent = '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/'
experiments = glob.glob(os.path.join(parent, '*/'))
for exp in experiments[18:]:
    root_path = os.path.join(exp, '3D')

    gt_path = os.path.join(root_path, 'gt')
    #gt_path = 'data/temp/gt'
    gt = sorted(glob.glob(os.path.join(gt_path, '*')))
    logging.info('GT files: {}'.format(len(gt)))
    logging.info(gt[:5])

    pred_path = os.path.join(root_path, 'pred')
    #pred_path = 'data/temp/pred'
    pred = sorted(glob.glob(os.path.join(pred_path, '*')))
    logging.info('Pred files: {}'.format(len(pred)))
    logging.info(pred[:5])

    # proof if we have one gt file for each prediction and vize versa
    p = set(os.path.basename(elem) for elem in pred)
    g = set(os.path.basename(elem) for elem in gt)
    logging.info(g-p)
    logging.info(p-g)
    logging.info(len(p.intersection(g)))
    try:
        compute_metrics_on_directories(gt_path, pred_path, results_path=os.path.join(root_path,'results.csv'))
    except Exception as e:
        logging.error('Failed with experiment: {}'.format(exp))
# Out:
# 2020-10-13 08:31:29,961 INFO GT files: 1030
# 2020-10-13 08:31:29,962 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/gt/0003-04NEJQUZ-2007-03-13_t12_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/gt/0003-04NEJQUZ-2007-03-13_t16_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/gt/0003-04NEJQUZ-2007-03-13_t20_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/gt/0003-04NEJQUZ-2007-03-13_t23_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/gt/0003-04NEJQUZ-2007-03-13_t5_msk.nrrd']
# 2020-10-13 08:31:29,965 INFO Pred files: 1030
# 2020-10-13 08:31:29,966 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/pred/0003-04NEJQUZ-2007-03-13_t12_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/pred/0003-04NEJQUZ-2007-03-13_t16_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/pred/0003-04NEJQUZ-2007-03-13_t20_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/pred/0003-04NEJQUZ-2007-03-13_t23_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/3D/pred/0003-04NEJQUZ-2007-03-13_t5_msk.nrrd']
# 2020-10-13 08:31:29,968 INFO set()
# 2020-10-13 08:31:29,968 INFO set()
# 2020-10-13 08:31:29,969 INFO 1030
# 2020-10-13 08:35:16,286 ERROR Failed with experiment: /mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_1st/
# 2020-10-13 08:35:16,287 INFO GT files: 0
# 2020-10-13 08:35:16,288 INFO []
# 2020-10-13 08:35:16,288 INFO Pred files: 0
# 2020-10-13 08:35:16,289 INFO []
# 2020-10-13 08:35:16,289 INFO set()
# 2020-10-13 08:35:16,290 INFO set()
# 2020-10-13 08:35:16,290 INFO 0
# 2020-10-13 08:35:16,292 ERROR Failed with experiment: /mnt/ssd/git/3d-mri-domain-adaption/data/predicted/temp/
# 2020-10-13 08:35:16,293 INFO GT files: 42
# 2020-10-13 08:35:16,293 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/gt/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/gt/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/gt/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/gt/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/gt/0000-24YLF77L_2007-11-19_ED_msk.nrrd']
# 2020-10-13 08:35:16,293 INFO Pred files: 42
# 2020-10-13 08:35:16,294 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/pred/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/pred/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/pred/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/pred/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/maskprob_2_ax_1_sax_1_unet_post/3D/pred/0000-24YLF77L_2007-11-19_ED_msk.nrrd']
# 2020-10-13 08:35:16,294 INFO set()
# 2020-10-13 08:35:16,294 INFO set()
# 2020-10-13 08:35:16,295 INFO 42
# 2020-10-13 08:37:11,706 INFO GT files: 50
# 2020-10-13 08:37:11,706 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/gt/patient001_frame01.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/gt/patient001_frame12.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/gt/patient002_frame01.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/gt/patient002_frame12.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/gt/patient009_frame01.nii.gz']
# 2020-10-13 08:37:11,707 INFO Pred files: 50
# 2020-10-13 08:37:11,707 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/pred/patient001_frame01.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/pred/patient001_frame12.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/pred/patient002_frame01.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/pred/patient002_frame12.nii.gz', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/gcn_excl_ax_acdc/3D/pred/patient009_frame01.nii.gz']
# 2020-10-13 08:37:11,708 INFO set()
# 2020-10-13 08:37:11,708 INFO set()
# 2020-10-13 08:37:11,708 INFO 50
# 2020-10-13 08:38:33,819 INFO GT files: 42
# 2020-10-13 08:38:33,820 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/gt/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/gt/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/gt/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/gt/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/gt/0000-24YLF77L_2007-11-19_ED_msk.nrrd']
# 2020-10-13 08:38:33,820 INFO Pred files: 42
# 2020-10-13 08:38:33,821 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/pred/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/pred/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/pred/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/pred/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/1_ax_1_sax_1_unet_NoPost/3D/pred/0000-24YLF77L_2007-11-19_ED_msk.nrrd']
# 2020-10-13 08:38:33,821 INFO set()
# 2020-10-13 08:38:33,821 INFO set()
# 2020-10-13 08:38:33,822 INFO 42
# 2020-10-13 08:40:26,130 INFO GT files: 80
# 2020-10-13 08:40:26,131 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/gt/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/gt/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/gt/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/gt/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/gt/0000-1E4PF7MR_2006-07-06_ED_msk.nrrd']
# 2020-10-13 08:40:26,132 INFO Pred files: 80
# 2020-10-13 08:40:26,132 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/pred/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/pred/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/pred/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/pred/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/baseline_cycle_unet_post_down/3D/pred/0000-1E4PF7MR_2006-07-06_ED_msk.nrrd']
# 2020-10-13 08:40:26,133 INFO set()
# 2020-10-13 08:40:26,133 INFO set()
# 2020-10-13 08:40:26,133 INFO 80
# 2020-10-13 08:43:03,313 INFO GT files: 42
# 2020-10-13 08:43:03,314 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/gt/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/gt/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/gt/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/gt/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/gt/0000-24YLF77L_2007-11-19_ED_msk.nrrd']
# 2020-10-13 08:43:03,315 INFO Pred files: 42
# 2020-10-13 08:43:03,315 INFO ['/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/pred/0000-0HQQW4ZN_2007-05-23_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/pred/0000-0HQQW4ZN_2007-05-23_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/pred/0000-13JLP3HN_2007-05-22_ED_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/pred/0000-13JLP3HN_2007-05-22_ES_msk.nrrd', '/mnt/ssd/git/3d-mri-domain-adaption/data/predicted/AX_to_SAX_to_AX/3D/pred/0000-24YLF77L_2007-11-19_ED_msk.nrrd']
# 2020-10-13 08:43:03,315 INFO set()
# 2020-10-13 08:43:03,316 INFO set()
# 2020-10-13 08:43:03,316 INFO 42

# %% [markdown]
# # Show all predictions between two relative borders

# %%
# explore outliers Dice
@interact
def explore_outliers(df_selected = ["df_dice", "df_hd", "df_vol"], min_=(0,1,0.1), max_=(0,1,0.1)):
    print(df_selected)
    
    df = globals().get(df_selected).copy()
    orders = list(df.variable.unique())
    print(df.describe())
    df = df[df['value'] >= df['value'].max() * float(min_)]
    df = df[df['value'] <= df['value'].max() * float(max_)]
    #orders = ["Dice LV", "Dice MYO", "Dice RV"]
    
    plt.rcParams.update({'font.size': 20})
    fig, (ax1) = plt.subplots(1, 1, figsize=(25,10), sharey=False)
    ax1 = sns.stripplot(x= 'variable',y = 'value', data=df,order=orders, ax=ax1)
    medians = df.groupby(['variable'])['value'].mean().round(2)
    sd = df.groupby(['variable'])['value'].std().round(2)
    nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]
    return df.Name
# Out:
# interactive(children=(Dropdown(description='df_selected', options=('df_dice', 'df_hd', 'df_vol'), value='df_di…

# %%
# explore outliers Dice

from ipywidgets import IntSlider

@interact
def explore_outliers(df_selected = ["df_dice", "df_hd", "df_vol"], 
                     low = IntSlider(min=0,max=3,step=1,value=0), 
                     high =IntSlider(min=0,max=3,step=1,value=3), 
                     examples=IntSlider(min=0,max=50,step=1,value=10), 
                     smallest=True):
    """
    Select a dataframe, define the label of interests and show the n best/worst examples
    params:
    df_selected: select "DICE", "vol difference" or "abolute vol" dataframe
    low: Interpret the labels as int list 0 - 3, define a range of labels with low and high, order: LV,MYO,RV
    high: upper labels limit
    examples: Define the number of lowest performer for this df and labels
    smallest: You can pick the smallest or highest dice scores with smallest=False/True
    """
    
    print(df_selected)
    
    # create a copy of the selected dataframe
    df = globals().get(df_selected).copy()
    # create a list of labels
    orders = sorted(list(df.variable.unique()))[low:high]
    # filter rows by selected labels
    df = df[df['variable'].isin(orders)]
    
    print(df.describe())
    if smallest:
        df = df.nsmallest(examples, columns=['value'])
    else:
         df = df.nlargest(examples, columns=['value'])
    #orders = ["Dice LV", "Dice MYO", "Dice RV"]
    
    plt.rcParams.update({'font.size': 20})
    fig, (ax1) = plt.subplots(1, 1, figsize=(25,10), sharey=False)
    ax1 = sns.stripplot(x= 'variable',y = 'value', data=df,order=orders, ax=ax1)
    medians = df.groupby(['variable'])['value'].mean().round(2)
    sd = df.groupby(['variable'])['value'].std().round(2)
    nobs = ['{}+/-{}'.format(m,s) for m,s in zip(medians, sd)]
    return df.Name
# Out:
# interactive(children=(Dropdown(description='df_selected', options=('df_dice', 'df_hd', 'df_vol'), value='df_di…
