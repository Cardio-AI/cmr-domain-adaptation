# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.notebook_imports import *
from pyforest import *


# define GPU id to use
# 0 = 1080 Bus ID 2
# 1 = Titan Bus ID 131
# 2 = Titan Bus ID 132
GPU_IDS = '1'
current_gpu = choose_gpu_by_id(GPU_IDS)
print(current_gpu)

# jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

sys.path.append('src/models/ext/neuron')
sys.path.append('src/models/ext/pynd-lib')
sys.path.append('src/models/ext/pytools-lib')

# import helpers
from src.utils.utils_io import Console_and_file_logger, init_config
from src.visualization.visualize import show_2D_or_3D
from src.data.dataset import get_img_msk_files_from_split_dir, load_acdc_files, get_train_data_from_df
from src.data.generators import DataGenerator, get_samples, MotionDataGenerator
from src.utils.unet_3d_metrics import weighted_dice_coefficient_loss
from src.models.ModelManager import get_model
from src.utils.KerasCallbacks import get_callbacks
import src.utils.my_metrics as metr
from src.models.src.networks import cvpr2018_net
from keras.losses import mean_squared_error as mse
from src.models.src.losses import Grad
from src.visualization.visualize import create_quiver_plot


# define experiment name for report, model and log paths + filenames
EXPERIMENT = 'motion/3D/acdc/ES_ED_masked_myo/'
now = datetime.datetime.now()

# image params, change for different input data/architecture
ARCHITECTURE = '3D' # 2D
DIM = [16, 224, 224] # [16,244,244]

SPACING = [7, 1.0,1.0] # used by sitk, opposite order than numpy or tensorflow!
IMG_CHANNELS = 1
MASK_VALUES = [0, 1, 2, 3]  
MASK_CLASSES = len(MASK_VALUES)
# Background = 0 = Y[:,:,0]
# RV = 1 = Y[:,:,1] 
# Myo = 2 = Y[:,:,2] 
# LV = 3 = Y[:,:,3]
AUGMENT = False
SHUFFLE = True
AUGMENT_GRID = False
RESAMPLE = False

# path params
DATASET = 'gcn'

MODEL_PATH = os.path.join(os.path.join('models', EXPERIMENT), str(now.strftime("%Y-%m-%d_%H_%M")))
TENSORBOARD_LOG_DIR = os.path.join(os.path.join('reports/tensorboard_logs', EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))
CONFIG_PATH = os.path.join(os.path.join('reports/configs/',EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))
HISTORY_PATH = os.path.join(os.path.join('reports/history/',EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))

# training params
GENERATOR_WORKER = 4 # if not set, use batchsize
seed = 42
BATCHSIZE =  1 # 32, 64, 24, 16, 1
INITIAL_EPOCH = 0
EPOCHS = 150
FOLDS = 4
EPOCHS_BETWEEN_CHECKPOINTS = 5
MONITOR_FUNCTION = 'loss'
MONITOR_MODE = 'min'
SAVE_MODEL_FUNCTION = 'loss'
SAVE_MODEL_MODE = 'min'
MASKING_VALUES = [2]
MASKING_IMAGE = True

# Network params
OPTIMIZER = 'Adam'  # Adam, Adagrad, RMSprop, Adadelta,  # https://keras.io/optimizers/
ACTIVATION = 'elu'  # 'elu' --> works well with binary_crossentropy and bce_dice_loss, relu does not work, it clips negative values, bse does return negative values
LEARNING_RATE = 0.001
DECAY = 0.0
EPSILON = 1e-08
DROPOUT_L1_L2 = 0.4 # higher dropout at the deeper layers
DROPOUT_L3_L4 = 0.4
DROPOUT_L5 = 0.5
BATCH_NORMALISATION = True
USE_UPSAMPLE = True # otherwise use transpose

metrics = [
    metr.dice_coef_labels,
    metr.dice_coef_myo,
    metr.dice_coef_lv,
    metr.dice_coef_rv,
]

LOSS_FUNCTION = metr.bce_dice_jac_loss

Console_and_file_logger(EXPERIMENT, logging.INFO)


# Define a config for param injection,
# save a serialized version, 
# make sure all paths exist
config = init_config(locals(), True)
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/data/git/cardio
# Using TensorFlow backend.
# ['gpu(0)']
# INFO:root:-------------------- Start --------------------
# 2019-12-03 00:01:13,685 INFO -------------------- Start --------------------
# INFO:root:Working directory: /mnt/data/git/cardio.
# 2019-12-03 00:01:13,686 INFO Working directory: /mnt/data/git/cardio.
# INFO:root:Log file: ./logs/motion/3D/acdc/ES_ED_masked_myo/.log
# 2019-12-03 00:01:13,687 INFO Log file: ./logs/motion/3D/acdc/ES_ED_masked_myo/.log

# %% [markdown]
# # Load 3D slices from patients with 5 labelled timesteps

# %%
#logging.getLogger().setLevel(logging.DEBUG)
# ACDC
from src.data.dataset import get_acdc_dataset_as_df
df = get_acdc_dataset_as_df('data/raw/ACDC/original/all/')
phase1 = df[df['phase']=='es']['files'].values
phase2 = df[df['phase']=='ed']['files'].values
#GCN
# just train on the motion between ED and ES --> Systolic phase
#df = pd.read_csv('reports/vae/3d_gcn.csv')
#phase1 = df[df['phase']=='ES']['x_path'].values
#phase2 = df[df['phase']=='ED']['x_path'].values
batch_generator = MotionDataGenerator(phase1, phase2, config)
len(phase1)
len(phase2)
df.head()
# Out:
# INFO:root:Create DataGenerator
# 2019-12-03 00:01:37,049 INFO Create DataGenerator
# INFO:root:Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 100
#  Augment_grid: False
#  Thread workers: 4
# 2019-12-03 00:01:37,051 INFO Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 100
#  Augment_grid: False
#  Thread workers: 4
# INFO:root:No augmentation
# 2019-12-03 00:01:37,051 INFO No augmentation
# 100
# 100
#    index pathology     patient  \
# 0      0       DCM  patient001
# 1      1       DCM  patient001
# 2      2       DCM  patient001
# 3      3       DCM  patient001
# 4      4       DCM  patient001
#
#                                                files  phase
# 0     data/raw/ACDC/original/all/patient001/Info.cfg    cfg
# 1  data/raw/ACDC/original/all/patient001/patient0...     ed
# 2  data/raw/ACDC/original/all/patient001/patient0...  ed_gt
# 3  data/raw/ACDC/original/all/patient001/patient0...     es
# 4  data/raw/ACDC/original/all/patient001/patient0...  es_gt

# %%
# Select batch generator output
x = ''
y = ''
@interact
def select_batch(batch = (0,len(batch_generator), 1)):
    global x, y
    input_ , output_ = batch_generator.__getitem__(batch)
    x = input_[0]
    y = output_[0]
    logging.info(x.shape)
    logging.info(y.shape)
# Out:
# interactive(children=(IntSlider(value=50, description='batch'), Output()), _dom_classes=('widget-interact',))

# %%
@interact
def select_image_in_batch(im = (0,x.shape[0]- 1, 1)):
    
    # define a different logging level to make the generator steps visible
    logging.getLogger().setLevel(logging.INFO)
    show_2D_or_3D(x[im])
    plt.show()
    show_2D_or_3D(y[im])
    plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='im', max=0), Output()), _dom_classes=('widget-interact',…

# %%
# create a new model
model = cvpr2018_net(config.get('DIM', [16, 224, 224]), enc_nf=[16,32,32,32], dec_nf=[32,32,32,32,16,3])
model.compile(optimizer=keras.optimizers.Adam(), loss=['mse', Grad('l2').loss],
                         loss_weights=[1.0, 0.01]) # values used by the CVPR paper

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16, 224, 224, 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 16, 224, 224, 0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 224, 224, 0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 8, 112, 112,  880         concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 8, 112, 112,  0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 4, 56, 56, 32 13856       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 4, 56, 56, 32 0           conv3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 2, 28, 28, 32 27680       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 2, 28, 28, 32 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 1, 14, 14, 32 27680       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 1, 14, 14, 32 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 1, 14, 14, 32 27680       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 1, 14, 14, 32 0           conv3d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 2, 28, 28, 32 0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2, 28, 28, 64 0           up_sampling3d_1[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 2, 28, 28, 32 55328       concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 2, 28, 28, 32 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 4, 56, 56, 32 0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 4, 56, 56, 64 0           up_sampling3d_2[0][0]
#                                                                  leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 4, 56, 56, 32 55328       concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 4, 56, 56, 32 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 8, 112, 112,  0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 112, 112,  0           up_sampling3d_3[0][0]
#                                                                  leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 8, 112, 112,  41504       concatenate_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 112, 112,  0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 8, 112, 112,  13840       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 112, 112,  0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 16, 224, 224, 0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 224, 224, 0           up_sampling3d_4[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 16, 224, 224, 1461        concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 224, 224, 0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# flow (Conv3D)                   (None, 16, 224, 224, 246         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# spatial_transformer_1 (SpatialT [(None, 16, 224, 224 0           input_1[0][0]
#                                                                  flow[0][0]
# ==================================================================================================
# Total params: 265,483
# Trainable params: 265,483
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file=os.path.join(config.get('CONFIG_PATH'),'model.png'), show_shapes=True)

# %%
initial_epoch = 0
# training

# start a new main process for this training to free gpu memory afterwards
logging.info('Fit model, start trainings process')
# fit model with trainingsgenerator
results = model.fit_generator(
    generator=batch_generator,
    epochs=200,
    callbacks = get_callbacks(config),
    steps_per_epoch = len(batch_generator),
    initial_epoch=initial_epoch,
    max_queue_size=30,
    workers=8,
    #use_multiprocessing=True,
    verbose=1)
# Out:
# INFO:root:Fit model, start trainings process
# 2019-12-03 00:02:00,307 INFO Fit model, start trainings process
# Epoch 1/200
# 100/100 [==============================] - 14s 139ms/step - loss: 0.0045 - spatial_transformer_1_loss: 0.0044 - flow_loss: 0.0040
# INFO:root:Saved model to disk: models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01
# 2019-12-03 00:02:19,189 INFO Saved model to disk: models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01
# Epoch 00001: loss improved from inf to 0.00445, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 2/200
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0025 - spatial_transformer_1_loss: 0.0024 - flow_loss: 0.0075
#
# Epoch 00002: loss improved from 0.00445 to 0.00252, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 3/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0020 - spatial_transformer_1_loss: 0.0019 - flow_loss: 0.0079
#
# Epoch 00003: loss improved from 0.00252 to 0.00202, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 4/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0017 - spatial_transformer_1_loss: 0.0017 - flow_loss: 0.0082
#
# Epoch 00004: loss improved from 0.00202 to 0.00173, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 5/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0017 - spatial_transformer_1_loss: 0.0016 - flow_loss: 0.0087
#
# Epoch 00005: loss did not improve from 0.00173
# Epoch 6/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0016 - spatial_transformer_1_loss: 0.0015 - flow_loss: 0.0091
#
# Epoch 00006: loss improved from 0.00173 to 0.00156, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 7/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0014 - spatial_transformer_1_loss: 0.0013 - flow_loss: 0.0090
#
# Epoch 00007: loss improved from 0.00156 to 0.00143, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 8/200
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0014 - spatial_transformer_1_loss: 0.0013 - flow_loss: 0.0093
#
# Epoch 00008: loss improved from 0.00143 to 0.00139, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 9/200
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0015 - spatial_transformer_1_loss: 0.0014 - flow_loss: 0.0103
#
# Epoch 00009: loss did not improve from 0.00139
# Epoch 10/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0017 - spatial_transformer_1_loss: 0.0016 - flow_loss: 0.0120
#
# Epoch 00010: loss did not improve from 0.00139
# Epoch 11/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0014 - spatial_transformer_1_loss: 0.0013 - flow_loss: 0.0113 2s - loss: 0.0014 - spatia
#
# Epoch 00011: loss did not improve from 0.00139
# Epoch 12/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0013 - spatial_transformer_1_loss: 0.0012 - flow_loss: 0.0103
#
# Epoch 00012: loss improved from 0.00139 to 0.00130, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 13/200
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0012 - spatial_transformer_1_loss: 0.0011 - flow_loss: 0.0101
#
# Epoch 00013: loss improved from 0.00130 to 0.00123, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 14/200
# 100/100 [==============================] - 10s 95ms/step - loss: 0.0012 - spatial_transformer_1_loss: 0.0011 - flow_loss: 0.0103
#
# Epoch 00014: loss improved from 0.00123 to 0.00120, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 15/200
# 100/100 [==============================] - 9s 86ms/step - loss: 0.0011 - spatial_transformer_1_loss: 0.0010 - flow_loss: 0.0099
#
# Epoch 00015: loss improved from 0.00120 to 0.00112, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 16/200
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0012 - spatial_transformer_1_loss: 0.0011 - flow_loss: 0.0105
#
# Epoch 00016: loss did not improve from 0.00112
# Epoch 17/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0011 - spatial_transformer_1_loss: 0.0010 - flow_loss: 0.0106
#
# Epoch 00017: loss did not improve from 0.00112
# Epoch 18/200
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0010 - spatial_transformer_1_loss: 9.4306e-04 - flow_loss: 0.0105
#
# Epoch 00018: loss improved from 0.00112 to 0.00105, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 19/200
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0011 - spatial_transformer_1_loss: 9.4400e-04 - flow_loss: 0.0107
#
# Epoch 00019: loss did not improve from 0.00105
# Epoch 20/200
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0011 - spatial_transformer_1_loss: 9.4910e-04 - flow_loss: 0.0107 1s - loss: 0.0010 - spatial_transformer_1_loss: 9.3326
#
# Epoch 00020: loss did not improve from 0.00105
# Epoch 21/200
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0011 - spatial_transformer_1_loss: 9.4543e-04 - flow_loss: 0.0110
#
# Epoch 00021: loss did not improve from 0.00105
# Epoch 22/200
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0014 - spatial_transformer_1_loss: 0.0013 - flow_loss: 0.0127
#
# Epoch 00022: loss did not improve from 0.00105
# Epoch 23/200
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0013 - spatial_transformer_1_loss: 0.0011 - flow_loss: 0.0125
#
# Epoch 00023: loss did not improve from 0.00105
# Epoch 24/200
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0010 - spatial_transformer_1_loss: 9.0100e-04 - flow_loss: 0.0116
#
# Epoch 00024: loss improved from 0.00105 to 0.00102, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 25/200
# 100/100 [==============================] - 9s 93ms/step - loss: 9.4713e-04 - spatial_transformer_1_loss: 8.3824e-04 - flow_loss: 0.0109
#
# Epoch 00025: loss improved from 0.00102 to 0.00095, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 26/200
# 100/100 [==============================] - 9s 87ms/step - loss: 9.1504e-04 - spatial_transformer_1_loss: 8.0700e-04 - flow_loss: 0.0108
#
# Epoch 00026: loss improved from 0.00095 to 0.00092, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 27/200
# 100/100 [==============================] - 9s 92ms/step - loss: 8.9895e-04 - spatial_transformer_1_loss: 7.9205e-04 - flow_loss: 0.0107
#
# Epoch 00027: loss improved from 0.00092 to 0.00090, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 28/200
# 100/100 [==============================] - 9s 92ms/step - loss: 8.8453e-04 - spatial_transformer_1_loss: 7.7884e-04 - flow_loss: 0.0106
#
# Epoch 00028: loss improved from 0.00090 to 0.00088, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 29/200
# 100/100 [==============================] - 9s 91ms/step - loss: 8.6494e-04 - spatial_transformer_1_loss: 7.5901e-04 - flow_loss: 0.0106
#
# Epoch 00029: loss improved from 0.00088 to 0.00086, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 30/200
# 100/100 [==============================] - 9s 90ms/step - loss: 8.5280e-04 - spatial_transformer_1_loss: 7.4818e-04 - flow_loss: 0.0105
#
# Epoch 00030: loss improved from 0.00086 to 0.00085, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 31/200
# 100/100 [==============================] - 9s 94ms/step - loss: 8.3060e-04 - spatial_transformer_1_loss: 7.2605e-04 - flow_loss: 0.0105
#
# Epoch 00031: loss improved from 0.00085 to 0.00083, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 32/200
# 100/100 [==============================] - 9s 93ms/step - loss: 8.1335e-04 - spatial_transformer_1_loss: 7.0915e-04 - flow_loss: 0.0104
#
# Epoch 00032: loss improved from 0.00083 to 0.00081, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 33/200
# 100/100 [==============================] - 9s 94ms/step - loss: 8.0039e-04 - spatial_transformer_1_loss: 6.9640e-04 - flow_loss: 0.0104
#
# Epoch 00033: loss improved from 0.00081 to 0.00080, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 34/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.9288e-04 - spatial_transformer_1_loss: 6.8952e-04 - flow_loss: 0.0103
#
# Epoch 00034: loss improved from 0.00080 to 0.00079, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 35/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.8333e-04 - spatial_transformer_1_loss: 6.8081e-04 - flow_loss: 0.0103
#
# Epoch 00035: loss improved from 0.00079 to 0.00078, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 36/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.7866e-04 - spatial_transformer_1_loss: 6.7604e-04 - flow_loss: 0.0103
#
# Epoch 00036: loss improved from 0.00078 to 0.00078, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 37/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.6794e-04 - spatial_transformer_1_loss: 6.6583e-04 - flow_loss: 0.0102
#
# Epoch 00037: loss improved from 0.00078 to 0.00077, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 38/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.6191e-04 - spatial_transformer_1_loss: 6.5954e-04 - flow_loss: 0.0102
#
# Epoch 00038: loss improved from 0.00077 to 0.00076, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 39/200
# 100/100 [==============================] - 9s 95ms/step - loss: 7.5664e-04 - spatial_transformer_1_loss: 6.5436e-04 - flow_loss: 0.0102
#
# Epoch 00039: loss improved from 0.00076 to 0.00076, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 40/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.5269e-04 - spatial_transformer_1_loss: 6.5067e-04 - flow_loss: 0.0102
#
# Epoch 00040: loss improved from 0.00076 to 0.00075, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 41/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.4914e-04 - spatial_transformer_1_loss: 6.4733e-04 - flow_loss: 0.0102
#
# Epoch 00041: loss improved from 0.00075 to 0.00075, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 42/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.4316e-04 - spatial_transformer_1_loss: 6.4116e-04 - flow_loss: 0.0102
#
# Epoch 00042: loss improved from 0.00075 to 0.00074, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 43/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.4028e-04 - spatial_transformer_1_loss: 6.3845e-04 - flow_loss: 0.0102
#
# Epoch 00043: loss improved from 0.00074 to 0.00074, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 44/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.3827e-04 - spatial_transformer_1_loss: 6.3645e-04 - flow_loss: 0.0102
#
# Epoch 00044: loss improved from 0.00074 to 0.00074, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 45/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.3604e-04 - spatial_transformer_1_loss: 6.3418e-04 - flow_loss: 0.0102
#
# Epoch 00045: loss improved from 0.00074 to 0.00074, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 46/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.3392e-04 - spatial_transformer_1_loss: 6.3234e-04 - flow_loss: 0.0102
#
# Epoch 00046: loss improved from 0.00074 to 0.00073, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 47/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.3087e-04 - spatial_transformer_1_loss: 6.2903e-04 - flow_loss: 0.0102 3s - loss: 7.088
#
# Epoch 00047: loss improved from 0.00073 to 0.00073, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 48/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.2955e-04 - spatial_transformer_1_loss: 6.2779e-04 - flow_loss: 0.0102
#
# Epoch 00048: loss improved from 0.00073 to 0.00073, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 49/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.2838e-04 - spatial_transformer_1_loss: 6.2686e-04 - flow_loss: 0.0102
#
# Epoch 00049: loss improved from 0.00073 to 0.00073, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 50/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.2720e-04 - spatial_transformer_1_loss: 6.2549e-04 - flow_loss: 0.0102
#
# Epoch 00050: loss improved from 0.00073 to 0.00073, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 51/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.2600e-04 - spatial_transformer_1_loss: 6.2449e-04 - flow_loss: 0.0102
#
# Epoch 00051: loss improved from 0.00073 to 0.00073, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 52/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.2479e-04 - spatial_transformer_1_loss: 6.2319e-04 - flow_loss: 0.0102
#
# Epoch 00052: loss improved from 0.00073 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 53/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.2355e-04 - spatial_transformer_1_loss: 6.2205e-04 - flow_loss: 0.0101
#
# Epoch 00053: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 54/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.2175e-04 - spatial_transformer_1_loss: 6.2019e-04 - flow_loss: 0.0102
#
# Epoch 00054: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 55/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.2101e-04 - spatial_transformer_1_loss: 6.1950e-04 - flow_loss: 0.0102
#
# Epoch 00055: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 56/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.2034e-04 - spatial_transformer_1_loss: 6.1881e-04 - flow_loss: 0.0102
#
# Epoch 00056: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 57/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1964e-04 - spatial_transformer_1_loss: 6.1828e-04 - flow_loss: 0.0101
#
# Epoch 00057: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 58/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1902e-04 - spatial_transformer_1_loss: 6.1754e-04 - flow_loss: 0.0101
#
# Epoch 00058: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 59/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1798e-04 - spatial_transformer_1_loss: 6.1653e-04 - flow_loss: 0.0101
#
# Epoch 00059: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 60/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1761e-04 - spatial_transformer_1_loss: 6.1619e-04 - flow_loss: 0.0101
#
# Epoch 00060: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 61/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1725e-04 - spatial_transformer_1_loss: 6.1575e-04 - flow_loss: 0.0102
#
# Epoch 00061: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 62/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1684e-04 - spatial_transformer_1_loss: 6.1540e-04 - flow_loss: 0.0101
#
# Epoch 00062: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 63/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1648e-04 - spatial_transformer_1_loss: 6.1512e-04 - flow_loss: 0.0101
#
# Epoch 00063: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 64/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1592e-04 - spatial_transformer_1_loss: 6.1440e-04 - flow_loss: 0.0102
#
# Epoch 00064: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 65/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1570e-04 - spatial_transformer_1_loss: 6.1428e-04 - flow_loss: 0.0101
#
# Epoch 00065: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 66/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1551e-04 - spatial_transformer_1_loss: 6.1407e-04 - flow_loss: 0.0101
#
# Epoch 00066: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 67/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1530e-04 - spatial_transformer_1_loss: 6.1390e-04 - flow_loss: 0.0101
#
# Epoch 00067: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 68/200
# 100/100 [==============================] - 10s 97ms/step - loss: 7.1508e-04 - spatial_transformer_1_loss: 6.1365e-04 - flow_loss: 0.0101
#
# Epoch 00068: loss improved from 0.00072 to 0.00072, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 69/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1478e-04 - spatial_transformer_1_loss: 6.1340e-04 - flow_loss: 0.0101
#
# Epoch 00069: loss improved from 0.00072 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 70/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1467e-04 - spatial_transformer_1_loss: 6.1327e-04 - flow_loss: 0.0101
#
# Epoch 00070: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 71/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1456e-04 - spatial_transformer_1_loss: 6.1315e-04 - flow_loss: 0.0101
#
# Epoch 00071: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 72/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1446e-04 - spatial_transformer_1_loss: 6.1307e-04 - flow_loss: 0.0101
#
# Epoch 00072: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 73/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1435e-04 - spatial_transformer_1_loss: 6.1292e-04 - flow_loss: 0.0101
#
# Epoch 00073: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 74/200
# 100/100 [==============================] - 10s 95ms/step - loss: 7.1418e-04 - spatial_transformer_1_loss: 6.1282e-04 - flow_loss: 0.0101
#
# Epoch 00074: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 75/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1412e-04 - spatial_transformer_1_loss: 6.1271e-04 - flow_loss: 0.0101
#
# Epoch 00075: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 76/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1407e-04 - spatial_transformer_1_loss: 6.1267e-04 - flow_loss: 0.0101
#
# Epoch 00076: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 77/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1401e-04 - spatial_transformer_1_loss: 6.1262e-04 - flow_loss: 0.0101
#
# Epoch 00077: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 78/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1395e-04 - spatial_transformer_1_loss: 6.1252e-04 - flow_loss: 0.0101
#
# Epoch 00078: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 79/200
# 100/100 [==============================] - 10s 96ms/step - loss: 7.1387e-04 - spatial_transformer_1_loss: 6.1251e-04 - flow_loss: 0.0101
#
# Epoch 00079: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 80/200
# 100/100 [==============================] - 9s 87ms/step - loss: 7.1384e-04 - spatial_transformer_1_loss: 6.1243e-04 - flow_loss: 0.0101
#
# Epoch 00080: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 81/200
# 100/100 [==============================] - 9s 95ms/step - loss: 7.1381e-04 - spatial_transformer_1_loss: 6.1240e-04 - flow_loss: 0.0101
#
# Epoch 00081: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 82/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1377e-04 - spatial_transformer_1_loss: 6.1238e-04 - flow_loss: 0.0101
#
# Epoch 00082: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 83/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1374e-04 - spatial_transformer_1_loss: 6.1234e-04 - flow_loss: 0.0101
#
# Epoch 00083: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 84/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1370e-04 - spatial_transformer_1_loss: 6.1229e-04 - flow_loss: 0.0101
#
# Epoch 00084: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 85/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1368e-04 - spatial_transformer_1_loss: 6.1228e-04 - flow_loss: 0.0101
#
# Epoch 00085: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 86/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1367e-04 - spatial_transformer_1_loss: 6.1227e-04 - flow_loss: 0.0101
#
# Epoch 00086: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 87/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1365e-04 - spatial_transformer_1_loss: 6.1227e-04 - flow_loss: 0.0101
#
# Epoch 00087: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 88/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1363e-04 - spatial_transformer_1_loss: 6.1223e-04 - flow_loss: 0.0101
#
# Epoch 00088: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 89/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1361e-04 - spatial_transformer_1_loss: 6.1221e-04 - flow_loss: 0.0101
#
# Epoch 00089: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 90/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1360e-04 - spatial_transformer_1_loss: 6.1220e-04 - flow_loss: 0.0101
#
# Epoch 00090: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 91/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1360e-04 - spatial_transformer_1_loss: 6.1219e-04 - flow_loss: 0.0101
#
# Epoch 00091: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 92/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1359e-04 - spatial_transformer_1_loss: 6.1218e-04 - flow_loss: 0.0101
#
# Epoch 00092: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 93/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1358e-04 - spatial_transformer_1_loss: 6.1218e-04 - flow_loss: 0.0101
#
# Epoch 00093: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 94/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1357e-04 - spatial_transformer_1_loss: 6.1217e-04 - flow_loss: 0.0101
#
# Epoch 00094: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 95/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1356e-04 - spatial_transformer_1_loss: 6.1216e-04 - flow_loss: 0.0101
#
# Epoch 00095: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 96/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1356e-04 - spatial_transformer_1_loss: 6.1216e-04 - flow_loss: 0.0101
#
# Epoch 00096: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 97/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1356e-04 - spatial_transformer_1_loss: 6.1216e-04 - flow_loss: 0.0101
#
# Epoch 00097: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 98/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1355e-04 - spatial_transformer_1_loss: 6.1215e-04 - flow_loss: 0.0101
#
# Epoch 00098: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 99/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1355e-04 - spatial_transformer_1_loss: 6.1214e-04 - flow_loss: 0.0101
#
# Epoch 00099: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 100/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1354e-04 - spatial_transformer_1_loss: 6.1214e-04 - flow_loss: 0.0101
#
# Epoch 00100: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 101/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1354e-04 - spatial_transformer_1_loss: 6.1214e-04 - flow_loss: 0.0101
#
# Epoch 00101: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 102/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1354e-04 - spatial_transformer_1_loss: 6.1214e-04 - flow_loss: 0.0101
#
# Epoch 00102: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 103/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1354e-04 - spatial_transformer_1_loss: 6.1214e-04 - flow_loss: 0.0101
#
# Epoch 00103: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 104/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1354e-04 - spatial_transformer_1_loss: 6.1214e-04 - flow_loss: 0.0101
#
# Epoch 00104: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 105/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00105: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 106/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00106: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 107/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00107: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 108/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00108: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 109/200
# 100/100 [==============================] - 10s 95ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00109: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 110/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00110: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 111/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00111: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 112/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00112: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 113/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00113: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 114/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00114: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 115/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00115: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 116/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00116: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 117/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00117: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 118/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00118: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 119/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1353e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00119: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 120/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1213e-04 - flow_loss: 0.0101
#
# Epoch 00120: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 121/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00121: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 122/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00122: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 123/200
# 100/100 [==============================] - 10s 97ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00123: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 124/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00124: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 125/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00125: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 126/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00126: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 127/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00127: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 128/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00128: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 129/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00129: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 130/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00130: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 131/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00131: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 132/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00132: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 133/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00133: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 134/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00134: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 135/200
# 100/100 [==============================] - 9s 88ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00135: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 136/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00136: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 137/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1352e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00137: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 138/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1212e-04 - flow_loss: 0.0101
#
# Epoch 00138: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 139/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00139: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 140/200
# 100/100 [==============================] - 9s 95ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00140: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 141/200
# 100/100 [==============================] - 9s 88ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00141: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 142/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00142: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 143/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00143: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 144/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00144: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 145/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00145: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 146/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00146: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 147/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00147: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 148/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00148: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 149/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00149: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 150/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00150: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 151/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00151: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 152/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00152: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 153/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00153: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 154/200
# 100/100 [==============================] - 9s 95ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00154: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 155/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1351e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00155: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 156/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1211e-04 - flow_loss: 0.0101
#
# Epoch 00156: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 157/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00157: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 158/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00158: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 159/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00159: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 160/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00160: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 161/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00161: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 162/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00162: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 163/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00163: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 164/200
# 100/100 [==============================] - 9s 88ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00164: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 165/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00165: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 166/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00166: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 167/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101 3s -
#
# Epoch 00167: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 168/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00168: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 169/200
# 100/100 [==============================] - 9s 88ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00169: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 170/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00170: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 171/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00171: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 172/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00172: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 173/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1350e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00173: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 174/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00174: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 175/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1210e-04 - flow_loss: 0.0101
#
# Epoch 00175: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 176/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00176: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 177/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00177: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 178/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00178: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 179/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00179: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 180/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00180: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 181/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00181: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 182/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101 3s -
#
# Epoch 00182: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 183/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00183: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 184/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00184: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 185/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00185: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 186/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00186: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 187/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00187: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 188/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00188: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 189/200
# 100/100 [==============================] - 9s 91ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00189: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 190/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00190: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 191/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1349e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00191: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 192/200
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00192: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 193/200
# 100/100 [==============================] - 9s 88ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00193: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 194/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00194: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 195/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1209e-04 - flow_loss: 0.0101
#
# Epoch 00195: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 196/200
# 100/100 [==============================] - 9s 94ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1208e-04 - flow_loss: 0.0101
#
# Epoch 00196: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 197/200
# 100/100 [==============================] - 9s 90ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1208e-04 - flow_loss: 0.0101
#
# Epoch 00197: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 198/200
# 100/100 [==============================] - 9s 92ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1208e-04 - flow_loss: 0.0101
#
# Epoch 00198: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 199/200
# 100/100 [==============================] - 9s 95ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1208e-04 - flow_loss: 0.0101
#
# Epoch 00199: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5
# Epoch 200/200
# 100/100 [==============================] - 9s 89ms/step - loss: 7.1348e-04 - spatial_transformer_1_loss: 6.1208e-04 - flow_loss: 0.0101
#
# Epoch 00200: loss improved from 0.00071 to 0.00071, saving model to models/motion/3D/acdc/ES_ED_masked_myo/2019-12-03_00_01/checkpoint.h5

# %%
@interact_manual
def load_config_interactive(config_file=sorted(glob.glob('reports/configs/motion/3D/gcn/ES_ED/**/*.json', recursive=False))):
    """
    load config, tranings history and model
    """
    from src.data.Dataset_utils import load_config
    logging.info(config_file)
    # load config with all params into global namespace, load = false --> no unet model loading
    glob_ = load_config(config_file=config_file, load=False)
    
    # update global namesspace to make config, model and evaluation score accessible
    globals().update(glob_)

    # load trained model
    # create a new empty model and load model weights
    # ED --> ES voxelmorph model 'models/motion/3D/gcn/2019-11-08_21_49'
    # ES --> ED vocelmorph model 'models/motion/3D/gcn/'
    # dataframe saved as 'reports/vae/3d_gcn_flowfield.csv'
    # vectorfields saved as 'data/interim/motion/3d/gcn/ed_es/'
    model_ = cvpr2018_net(config.get('DIM', [16, 224, 224]), enc_nf=[16,32,32,32], dec_nf=[32,32,32,32,16,3])
    logging.info('model created')
    #model_.compile(optimizer=keras.optimizers.Adam(), loss=['mse', Grad('l2').loss], loss_weights=[1.0, 0.01]) # values used by the CVPR paper
    model_.load_weights(os.path.join(config['MODEL_PATH'],'checkpoint.h5'))
    logging.info('weights loaded')
    globals()['model'] = model_
    logging.info('model and weights loaded successfully')
# Out:
# interactive(children=(Dropdown(description='config_file', options=('reports/configs/motion/3D/gcn/ES_ED/2019-1…

# %%
# ACDC
from src.data.dataset import get_acdc_dataset_as_df
df = get_acdc_dataset_as_df('data/raw/ACDC/original/all/')
#df = df[df['pathology'] == 'RV']
phase1 = df[df['phase']=='es']['files'].values
phase2 = df[df['phase']=='ed']['files'].values
df.pathology.unique()
#GCN
#df = pd.read_csv('reports/vae/3d_gcn.csv')
#phase1 = df[df['phase']=='ES']['x_path'].values
#phase2 = df[df['phase']=='ED']['x_path'].values
test_config = config.copy()
test_config['SHUFFLE'] = False
test_config['BATCHSIZE'] = 1
test_config['AUGMENT_GRID'] = False
test_generator = MotionDataGenerator(phase1, phase2, test_config)
# Out:
# array(['DCM', 'HCM', 'MINF', 'NOR', 'RV'], dtype=object)
# INFO:root:Create DataGenerator
# 2019-12-03 15:15:41,173 INFO Create DataGenerator
# INFO:root:Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 100
#  Augment_grid: False
#  Thread workers: 4
# 2019-12-03 15:15:41,174 INFO Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 100
#  Augment_grid: False
#  Thread workers: 4
# INFO:root:No augmentation
# 2019-12-03 15:15:41,175 INFO No augmentation

# %%
df.head()
# Out:
#    index pathology     patient  \
# 0      0       DCM  patient001
# 1      1       DCM  patient001
# 2      2       DCM  patient001
# 3      3       DCM  patient001
# 4      4       DCM  patient001
#
#                                                files  phase
# 0     data/raw/ACDC/original/all/patient001/Info.cfg    cfg
# 1  data/raw/ACDC/original/all/patient001/patient0...     ed
# 2  data/raw/ACDC/original/all/patient001/patient0...  ed_gt
# 3  data/raw/ACDC/original/all/patient001/patient0...     es
# 4  data/raw/ACDC/original/all/patient001/patient0...  es_gt

# %%
# Select batch generator output
x = None
y = None
input_ = None
warped = None
flowfield = None
@interact
def select_batch(batch = (0,len(test_generator), 1)):
    global x, y, input_, warped, flowfield
    input_ , output_ = test_generator.__getitem__(batch)
    x = input_[0]
    y = output_[0]
    logging.info(x.shape)
    logging.info(y.shape)
    
    pred = model.predict(input_)
    warped, flowfield = pred
    warped.shape
    flowfield.shape
    flowfield[0].mean()
# Out:
# interactive(children=(IntSlider(value=50, description='batch'), Output()), _dom_classes=('widget-interact',))

# %%
@interact_manual
def show_flowfield(img = (0,x.shape[0]- 1)):
    
    from src.visualization.visualize import create_quiver_plot
    from src.data.preprocess import normalise_image
    
    nrows = x.shape[1]
    ncols = 7
    fig, axes = plt.subplots(nrows,ncols, figsize=(ncols*4,nrows*4))
    fig.subplots_adjust(hspace=0, wspace=0)
    
    axes[0,0].set_title('X-flow')
    axes[0,1].set_title('Y-flow')
    axes[0,2].set_title('image phase 1')
    axes[0,3].set_title('image_warped')
    axes[0,4].set_title('image phase 2')
    axes[0,5].set_title('rgb flow')
    axes[0,6].set_title('quiver flowfield')
    
    for i in range(axes.shape[0]):
        
        axes[i,0].imshow(flowfield[img,i,:,:,1]);
        axes[i,1].imshow(flowfield[img,i,:,:,2]);
        axes[i,2].imshow(x[img,i,:,:,0], cmap='gray')
        axes[i,3].imshow(warped[img,i,:,:,0], cmap='gray') # x warped, should bee similar to y
        axes[i,4].imshow(y[img,i,:,:,0], cmap='gray') # target
        # diff_ = y[img,i,:,:,0]- warped[img,i,:,:,0]
        # axes[i,5].imshow(diff_) # difference
        axes[i,5].imshow(normalise_image(flowfield[img, i, :, :, :]))
        axes[i,6] = create_quiver_plot(flowfield[img, i], axes[i,6])

    plt.tight_layout()
    plt.savefig('reports/motion/3D/gcn/systolic_movement_example_2.svg')
# Out:
# interactive(children=(IntSlider(value=0, description='img', max=0), Button(description='Run Interact', style=B…

# %%
@interact
def plot_quiver_from_motion(img=(0,flowfield.shape[0]-1), z=(0, flowfield.shape[1]- 1)):
    
    """
    This is an interact method for Jupyter.
    For usage in a python module, params needs to be changed
    flowfield is a global variable with the shape batchsize, z-axis, x-axis, y-axis (output from Voxelmorph)
    :param img: int - index which image should be selected
    :param z: int - define the z-axis
    :return: plot image into jupyter
    """
    
    from src.data.preprocess import normalise_image, filter_small_vectors_batch
    from mpl_toolkits.axes_grid1 import make_axes_locatable
    
    global x, flowfield, warped
    fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize=(34,6))
    
    print(flowfield.shape)
    
    ax1.set_title('Original image z={}'.format(z))
    ax1.imshow(x[img, z, :,:,0], cmap='gray')
    
    ax2 = create_quiver_plot(flowfield[img, z,...], ax2)
    
    ax3.set_title('RGB flow')
    flow = flowfield[img, z, ...].copy()
    flow_ = flowfield[img, z, ...].copy()
    im3 = ax3.imshow(normalise_image(flow))
    divider = make_axes_locatable(ax3)
    cax3 = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im3, cax=cax3, orientation='vertical')
    
    filtered_flow = filter_small_vectors_batch(flow,(-0.05,0.05), (-0.2,0.2), (-0.3,0.3))
    im4 = ax4.imshow(filtered_flow)
    
    ax5.set_title('Target image  z={}'.format(z))
    ax5.imshow(y[img,z,:,:,0], cmap='gray')
    
    plt.savefig('reports/motion/3D/gcn/systolic_movement_example_filtered.png')
    plt.show()
    
    border = 50
    ax1 = create_quiver_plot(flow[border:-border,border:-border,:], N=3, scale=1)
    f_ = filter_small_vectors_batch(flow, normalize=False)
    ax2 = create_quiver_plot(f_[border:-border,border:-border,:], N=3, scale=1)
    plt.show()
# Out:
# interactive(children=(IntSlider(value=0, description='img', max=0), IntSlider(value=7, description='z', max=15…

# %% [markdown]
# # Predict Flowfields for all 3D GCN volumes, save Flowfields as numpy, save f_name in dataframe

# %%
#t1_df = pd.concat([df[df['t_norm'] == 0], df[df['t_norm'] == 1], df[df['t_norm'] == 2], df[df['t_norm'] == 3]])
#t2_df = pd.concat([df[df['t_norm'] == 1], df[df['t_norm'] == 2], df[df['t_norm'] == 3], df[df['t_norm'] == 4]])
#t1_df.shape
# Out:
# (808, 147)

# %%
test_config = config.copy()
test_config['SHUFFLE'] = False
test_config['BATCHSIZE'] = 1
test_config['AUGMENT_GRID'] = False
test_generator = MotionDataGenerator(phase1, phase2, test_config)
# Out:
# INFO:root:Create DataGenerator
# 2019-12-03 15:15:57,021 INFO Create DataGenerator
# INFO:root:Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 100
#  Augment_grid: False
#  Thread workers: 4
# 2019-12-03 15:15:57,023 INFO Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 100
#  Augment_grid: False
#  Thread workers: 4
# INFO:root:No augmentation
# 2019-12-03 15:15:57,024 INFO No augmentation

# %%
pred = model.predict_generator(test_generator)

warped, flowfield = pred
warped.shape
flowfield.shape
# Out:
# (100, 16, 224, 224, 1)
# (100, 16, 224, 224, 3)

# %%
# get the same shape of dataframe we used for training
df_motion = df[df['phase'].isin(['es'])]
df_motion.shape
# Out:
# (100, 5)

# %%
# write the flowfields as numpz images to disk
file_root = 'data/interim/motion/3d/acdc/es_ed_myo/'
f_names = list()
ensure_dir(file_root)
#for patient, t, flowfield_3d in zip(df_motion['patient'], df_motion['t_norm'], flowfield):
for patient, flowfield_3d in zip(df_motion['patient'], flowfield):
    f_path = os.path.join(file_root, 'flowfield_3d_acdc_{}.npy'.format(patient))
    f_names.append(f_path)
    np.save(f_path, flowfield_3d)

# store path to motions in new dataset
df_motion.shape
len(f_names)
df_motion['flowfield_3d_myo'] = f_names
# Out:
# (100, 5)
# 100
# /home/sven/anaconda3/envs/dl/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_motion.to_csv('reports/vae/3d_gcn_systolic_flowfield.csv')

# %%
df_motion = pd.read_csv('reports/vae/3d_gcn_systolic_flowfield.csv')

# %%
df_motion = df_motion.drop(['flowfield_3d_gcn'], axis=1)
df_motion.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  background   rv  myo  lv  \
# 0           1             1       11589   98   35  37
# 1           6             6        7076  166  110  81
# 2          11            11       10521  145   57  56
# 3          17            17       11228  143   63  64
# 4          21            21       10953  183  127  62
#
#                                               y_path   t  t_norm  \
# 0  data/raw/GCN/3D/train/0003-04NEJQUZ-2007-03-13...  12       1
# 1  data/raw/GCN/3D/train/0006-0AE4R74L-1900-01-01...   3       1
# 2  data/raw/GCN/3D/train/0007-0HQQW4ZN-2007-05-23...  10       1
# 3  data/raw/GCN/3D/train/0008-0PTV75MP-2005-06-27...   7       2
# 4  data/raw/GCN/3D/train/0010-0RPELLU8-2007-02-13...   6       1
#
#                                             y_path.1  ...  \
# 0  data/raw/GCN/3D/train/0003-04NEJQUZ-2007-03-13...  ...
# 1  data/raw/GCN/3D/train/0006-0AE4R74L-1900-01-01...  ...
# 2  data/raw/GCN/3D/train/0007-0HQQW4ZN-2007-05-23...  ...
# 3  data/raw/GCN/3D/train/0008-0PTV75MP-2005-06-27...  ...
# 4  data/raw/GCN/3D/train/0010-0RPELLU8-2007-02-13...  ...
#
#   tricuspid insufficiency grades 0-4 tricinsuf   Last Report Date_y  \
# 0                                          3.0  2018-01-02 00:00:00
# 1                                          NaN  2016-05-25 00:00:00
# 2                                          1.0  2016-10-12 00:00:00
# 3                                          NaN  2017-09-14 00:00:00
# 4                                          1.0  2017-06-01 00:00:00
#
#    PVR nach MRT y/n             Date PVR Outcome y/n  \
# 0     y (Homograft)  2011-10-11 00:00:00           n
# 1                 n                  NaN           n
# 2        y (Sapien)  2016-10-12 00:00:00           y
# 3                 n                  NaN           n
# 4     y (Homograft)  2008-09-23 00:00:00           n
#
#                                       Type Outcome_y         Date Outcome  \
# 0                                                NaN                  NaN
# 1  atrial flutter first occured 07/2002, since th...                  NaN
# 2                                   slow VT  06/2016  2016-06-01 00:00:00
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#         patient_unique  phase  \
# 0  04NEJQUZ-2007-03-13     ES
# 1  0AE4R74L-1900-01-01     ES
# 2  0HQQW4ZN-2007-05-23     ES
# 3  0PTV75MP-2005-06-27     ES
# 4  0RPELLU8-2007-02-13     ES
#
#                                     flowfield_3d_myo
# 0  data/interim/motion/3d/gcn/es_ed_myo/flowfield...
# 1  data/interim/motion/3d/gcn/es_ed_myo/flowfield...
# 2  data/interim/motion/3d/gcn/es_ed_myo/flowfield...
# 3  data/interim/motion/3d/gcn/es_ed_myo/flowfield...
# 4  data/interim/motion/3d/gcn/es_ed_myo/flowfield...
#
# [5 rows x 152 columns]

# %% [markdown]
# # load all ED images, masks, and all ED images masks, calculate the vectorfields and save all three files for each volume

# %%
from src.data.generators import DataGenerator
# get the same shape of dataframe we used for training

df = pd.read_csv('reports/vae/3d_gcn.csv')
test_config = config.copy()
test_config['SHUFFLE'] = False
test_config['BATCHSIZE'] = 1
test_config['AUGMENT_GRID'] = False

phase1 = df[df['phase']=='ED']
phase2 = df[df['phase']=='ES']
    
test_generator = MotionDataGenerator(phase1['x_path'].values, phase2['x_path'].values, test_config)
generator1 = DataGenerator(phase1['x_path'].values, phase1['y_mask'].values, test_config)
generator2 = DataGenerator(phase2['x_mask'].values, phase2['y_mask'].values, test_config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-37aa16977cb4> in <module>
#      11 phase2 = df[df['phase']=='ES']
#      12
# ---> 13 test_generator = MotionDataGenerator(phase1['x_path'].values, phase2['x_path'].values, test_config)
#      14 generator1 = DataGenerator(phase1['x_path'].values, phase1['y_mask'].values, test_config)
#      15 generator2 = DataGenerator(phase2['x_mask'].values, phase2['y_mask'].values, test_config)
#
# /mnt/data/git/cardio/src/data/generators.py in __init__(self, x, y, config)
#     438
#     439     def __init__(self, x=None, y=None, config={}):
# --> 440         super(MotionDataGenerator, self).__init__(x=x, y=y, config=config)
#     441
#     442         self.X_SHAPE = np.empty((self.BATCHSIZE, *self.DIM, self.IMG_CHANNELS), dtype=np.float32)
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
# get all flowfields
pred = model.predict_generator(test_generator)

warped, flowfield = pred
warped.shape
flowfield.shape
# Out:
# (203, 16, 224, 224, 3)

# %%
# get all input and output files
i1 = list()
i2 = list()
i_1 = list()
m_1 = list()
i_2 = list()
m_2 = list()

for (image1, image2), (image_1, mask_1), (image_2, mask_2) in zip(test_generator, generator1, generator2):
    i1.append(image1[0][0][...,0])
    i2.append(image2[0][0][...,0])
    i_1.append(image_1[0][...,0])
    m_1.append(mask_1[0])
    i_2.append(image_2[0][...,0])
    m_2.append(mask_2[0])
    
i1 = np.stack(i1, axis=0)
i2 = np.stack(i2, axis=0)
i_1 = np.stack(i_1, axis=0)
m_1 = np.stack(m_1, axis=0)
i_2 = np.stack(i_2, axis=0)
m_2 = np.stack(m_2, axis=0)
print(i1.shape)
print(i2.shape)
print(i_1.shape)
print(m_1.shape)
print(i_2.shape)
print(m_2.shape)
# Out:
# (203, 16, 224, 224)
# (203, 16, 224, 224)
# (203, 16, 224, 224)
# (203, 16, 224, 224, 4)
# (203, 16, 224, 224)
# (203, 16, 224, 224, 4)

# %%
# cut one vector out
img = 101
z = 8
f_ = flowfield[img][z]
print(f_.shape)

N = 4
nx = f_.shape[0]//N

f_x = f_[...,1]
print('f_x', f_x.shape)
plt.imshow(f_x)
plt.show()

Fx = f_x[::N, ::N]
print('fx', Fx.shape)
plt.imshow(Fx)
plt.show()


nrows, ncols = Fx.shape

plt.imshow(i1[img][z])
plt.show()

plt.imshow(i2[img][z])
plt.show()

f_n = normalise_image(f_)

plt.imshow(f_n)
plt.show()

f_n_m = f_ * np.stack([m_2[img][z][...,2], m_2[img][z][...,2], m_2[img][z][...,2]], axis=-1)
plt.imshow(f_n_m)
plt.show()

flow_z = f_[...,0].copy()
flow_x = f_[...,1].copy()
flow_y = f_[...,2].copy()

# filter small z movements
flow_z[(flow_z > -0.7) & (flow_z < 0.7)] = 0
# filter small x movements
flow_x[(flow_x > -2.5) & (flow_x < 1.5)] = 0
# filter small y movements
flow_y[(flow_y > -2.5) & (flow_y < 1.5)] = 0
flow_ = np.stack([flow_z, flow_x, flow_y], axis=-1)

create_quiver_plot(f_)
create_quiver_plot(f_n_m)

fig, ax = plt.subplots(figsize=(10, 12))
ax.imshow(i2[img][z], alpha=0.5)
create_quiver_plot(flow_, ax)
# Out:
# (224, 224, 3)
# f_x (224, 224)
# fx (56, 56)
# 2019-11-18 16:57:34,501 WARNING Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from src.visualization.visualize import create_quiver_plot
from src.data.preprocess import normalise_image
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'last'

# write the flowfields as numpy images to disk
file_root = 'data/interim/motion/3d/gcn/ed_es/'
flow_names = list()
mask1_names = list()
mask2_names = list()
ensure_dir(file_root)

z = 6
patient = 125

n = 0

for flowfield_3d, (img1, msk1), (img2, msk2) in zip(flowfield, generator1, generator2):
    if n==patient:
        print(img1.shape)
        print(msk1.shape)
        print(flowfield_3d.shape)
        img1 = img1[0,z,:,:,0]
        msk1 = msk1[0,z,:,:,:]
        img2 = img2[0,z,:,:,0]
        msk2 = msk2[0,z,:,:,:]
        
        flow = flowfield_3d[z,...]
        flow_ = flow.copy()
        flow_masked_ = flow.copy()
        
        print(flow[100,125,:])
        
        #patient = row['patient']
        #t = row['t_norm']
        
        # image & mask
        show_2D_or_3D(img1,msk1)
        plt.show()
        show_2D_or_3D(img2,msk2)
        plt.show()
        
        fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize=(34,6))
        
        flow_n = normalise_image(flow.copy())
        flow_masked_n = flow_n * np.stack([msk2[...,2], msk2[...,2], msk2[...,2]], axis=-1).astype(np.bool)
        flow_masked_[~np.stack([msk2[...,2], msk2[...,2], msk2[...,2]], axis=-1).astype(np.bool)] = 0
        
        # flowfield normalised
        ax1.imshow(flow_n);
        ax1.set_axis_off();

        # flowfield masked and normalised
        ax2.imshow(flow_masked_n);
        ax2.set_axis_off();
        
        flow_z = flow[...,0].copy()
        flow_x = flow[...,1].copy()
        flow_y = flow[...,2].copy()

        # flowfield filter by small vectors
        # filter small z movements
        flow_z[(flow_z > -0.7) & (flow_z < 0.7)] = flow.min()
        # filter small x movements
        flow_x[(flow_x > -1.5) & (flow_x < 1.5)] = flow.min()
        # filter small y movements
        flow_y[(flow_y > -1.5) & (flow_y < 1.5)] = flow.min()
        flow = np.stack([flow_z, flow_x, flow_y], axis=-1)
        # show flowfield as rgb with small vectors filtered
        ax3.imshow(normalise_image(flow));
        ax3.set_axis_off();
        
        # create quiver plot
        ax4 = create_quiver_plot(flow_[...,1:], ax4);
        
        # 
        ax4 = create_quiver_plot(flow_masked_, ax5);

    if n>patient:
        print('break')
        break
        
    n = n + 1
# Out:
# 2019-11-18 16:11:19,110 INFO Image-shape: (224, 224)
# 2019-11-18 16:11:19,111 INFO Image data points: 45591
# 2019-11-18 16:11:19,112 INFO Image mean: 0.151
# 2019-11-18 16:11:19,113 INFO Image max: 1.000
# 2019-11-18 16:11:19,115 INFO Image min: 0.000
# 2019-11-18 16:11:19,115 INFO Mask-shape: (224, 224, 3)
# 2019-11-18 16:11:19,116 INFO RV mask data points: 1092
# 2019-11-18 16:11:19,117 INFO Myo mask data points: 649
# 2019-11-18 16:11:19,117 INFO LV mask data points: 1343
# 2019-11-18 16:11:19,118 INFO RV mask 0.02176339365541935% of total pixels.
# 2019-11-18 16:11:19,118 INFO Myo mask 0.012934470549225807% of total pixels.
# 2019-11-18 16:11:19,119 INFO LV mask 0.02676578424870968% of total pixels.
# (1, 16, 224, 224, 1)
# (1, 16, 224, 224, 4)
# (16, 224, 224, 3)
# [-0.93358546 -1.2738464   2.950707  ]
# 2019-11-18 16:11:19,260 INFO Image-shape: (224, 224)
# 2019-11-18 16:11:19,262 INFO Image data points: 45436
# 2019-11-18 16:11:19,263 INFO Image mean: 0.134
# 2019-11-18 16:11:19,264 INFO Image max: 0.967
# 2019-11-18 16:11:19,266 INFO Image min: 0.000
# 2019-11-18 16:11:19,267 INFO Mask-shape: (224, 224, 3)
# 2019-11-18 16:11:19,267 INFO RV mask data points: 1060
# 2019-11-18 16:11:19,268 INFO Myo mask data points: 653
# 2019-11-18 16:11:19,268 INFO LV mask data points: 715
# 2019-11-18 16:11:19,269 INFO RV mask 0.021125636994838715% of total pixels.
# 2019-11-18 16:11:19,269 INFO Myo mask 0.013014189898967743% of total pixels.
# 2019-11-18 16:11:19,270 INFO LV mask 0.014249840751290321% of total pixels.
# break

# %%
def create_quiver_plot_temp(flowfield_2d=None, ax=None):
    """
    Function to create an easy flowfield from the voxelmorph output
    Needs a 2D flowfield, function can handle 2D or 3D vectors as channels
    :param flowfield_2d: numpy array with shape x, y, vectors
    :param ax: matplotlib ax object which should be used for plotting,
    create a new ax object if none is given
    :return: ax to plot or save
    """

    N = 4  # take only every n vector
    nx = 224  # define ticks in x
    ny = 224  # define ticks in y
    if not ax:
        fig, ax = plt.subplots(figsize=(10, 12))

    # extract flowfield for x and y
    if flowfield_2d.shape[-1] == 3:  # originally a 3d flowfield
        print('3')
        X_ = flowfield_2d[..., 1]
        Y_ = flowfield_2d[..., 2]
    elif flowfield_2d.shape[-1] == 2:  # 2d flowfield
        X_ = flowfield_2d[..., 0]
        Y_ = flowfield_2d[..., 1]

    # slice flowfield, take every N value
    Fx = X_[::N, ::N]
    Fy = Y_[::N, ::N]
    nrows, ncols = Fx.shape

    # create a grid with the size nx/ny and ncols/nrows
    x_ = np.linspace(0, nx, ncols)
    y_ = np.linspace(0, ny, nrows)
    xi, yi = np.meshgrid(x_, y_, indexing='xy')

    # plot
    ax.set_title('Flowfield')
    ax.quiver(xi, yi, Fx, Fy, alpha=.5)
    ax.quiver(xi, yi, Fx, Fy, linewidth=.5)
    ax.set_ylim(ax.get_ylim()[1], ax.get_ylim()[0])
    return ax

# %%
for patient, t, flowfield_3d in zip(df_motion['patient'], df_motion['t_norm'], flowfield):
    f_path = os.path.join(file_root, 'flowfield_3d_{}_{}.npy'.format(patient, t))
    flow_names.append(f_path)

# store path to motions in new dataset
df_motion.shape
len(flow_names)
df_motion['flowfield_3d'] = flow_names

# %%
n = 0
for (i1, m1), (i2,m2) in zip(generator1, generator2):
    if n<1:
        print(i1.shape)
        print(m1.shape)
        show_2D_or_3D(i1[0,...,0],m1[0,...])
        show_2D_or_3D(i2[0,...,0],m2[0,...])
        m = m1 + m2
        m.shape
        show_2D_or_3D(i2[0,...,0],m[0,...])
    else:
        break
    n = n +1
# Out:
# (1, 16, 224, 224, 1)
# (1, 16, 224, 224, 4)
# (1, 16, 224, 224, 4)
