# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.notebook_imports import *
from pyforest import *


# define GPU id to use
# 0 = 1080 Bus ID 2
# 1 = Titan Bus ID 131
# 2 = Titan Bus ID 132
gpu_id = '0'
current_gpu = choose_gpu_by_id(gpu_id)

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2


from src.utils.utils_io import Console_and_file_logger, init_config
from src.visualization.visualize import show_2D_or_3D
from src.data.dataset import get_img_msk_files_from_split_dir
from src.data.generators import DataGenerator, get_samples
from src.utils.unet_3d_metrics import weighted_dice_coefficient_loss
from src.models.ModelManager import get_model
from src.utils.KerasCallbacks import get_callbacks
from keras.utils import plot_model
import src.utils.my_metrics as metr


# define experiment name for report, model and log paths + filenames
EXPERIMENT = '3D/downsampleZ/1_1_1_1'
now = datetime.datetime.now()

# image params, change for different input data/architecture
ARCHITECTURE = '3D' # 2D
DIM = [16, 224, 224] # need z = 16
SPACING = [8, 1.0,1.0] # cbe carefull check if spacing is used by sitk (opposite order than numpy or tensorflow)
IMG_CHANNELS = 1
MASK_VALUES = [0, 1, 2, 3]  
MASK_CLASSES = len(MASK_VALUES)
# Background = 0 = Y[:,:,0]
# RV = 1 = Y[:,:,1] 
# Myo = 2 = Y[:,:,2] 
# LV = 3 = Y[:,:,3]
AUGMENT = False
SHUFFLE = True
AUGMENT_GRID = True
RESAMPLE = False


# training params
GENERATOR_WORKER = 8 # if not set use batchsize
seed = 42
BATCHSIZE =  8 # 32, 64, 16, 1
INITIAL_EPOCH = 0
EPOCHS = 150
FOLDS = 4
EPOCHS_BETWEEN_CHECKPOINTS = 5
MONITOR_FUNCTION = 'val_dice_coef_labels'
MONITOR_MODE = 'max'

# Network params
OPTIMIZER = 'Adam'  # Adam, Adagrad, RMSprop, Adadelta,  # https://keras.io/optimizers/
ACTIVATION = 'elu'  # 'elu' --> works well with binary_crossentropy and bce_dice_loss, relu does not work, it clips negative values, bse does return negative values
LEARNING_RATE = 0.001
DECAY = 0.0
EPSILON = 1e-08
DROPOUT_L1_L2 = 0.3 # best with 0.4 and other 0.5
DROPOUT_L3_L4 = 0.4
DROPOUT_L5 = 0.5
BATCH_NORMALISATION = True

# path params
DATASET = 'tetra'  # 'acdc' # or 'tetra'
TRAIN_PATH = 'data/raw/tetra/3D/train/'
VAL_PATH = 'data/raw/tetra/3D/val/'
TEST_PATH = 'data/raw/tetra/3D/test/'

MODEL_PATH = os.path.join(os.path.join('models', EXPERIMENT), str(now.strftime("%Y-%m-%d_%H_%M")))
TENSORBOARD_LOG_DIR = os.path.join(os.path.join('reports/tensorboard_logs', EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))
CONFIG_PATH = os.path.join(os.path.join('reports/configs/',EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))
HISTORY_PATH = os.path.join(os.path.join('reports/history/',EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))

#metrics = [jaccard_coef, jaccard_coef_background, jaccard_coef_rv, jaccard_coef_lv, jaccard_coef_myo]
metrics = [
    metr.dice_coef_labels,
    metr.dice_coef_myo,
    metr.dice_coef_lv,
    metr.dice_coef_rv,
    
]

#LOSS_FUNCTION = keras.losses.categorical_crossentropy
#weights = np.array([1,2,2,3]) # Class one at 1, class 2, 10 times the normal weights, class 3 and 4 20x.
#LOSS_FUNCTION = weighted_categorical_crossentropy(weights)
#LOSS_FUNCTION = cce_dice_loss
LOSS_FUNCTION = metr.bce_dice_jac_loss

Console_and_file_logger(EXPERIMENT, logging.INFO)


# Define a config for param injection,
# save a serialized version, 
# make sure all paths exist
config = init_config(locals(), True)

# set warnings lvl for skimage
#warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
# define a Tensorflow config
tf_config = tf.ConfigProto()
tf_config.gpu_options.allow_growth = True
tf_session = tf.Session(config=tf_config)
tf.keras.backend.set_session(tf_session)
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/data/git/cardio
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12896537073890217170
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15677399688762700131
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 23132218983
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4679361744906887288
# physical_device_desc: "device: 0, name: TITAN RTX, pci bus id: 0000:01:00.0, compute capability: 7.5"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8360648327538251580
# physical_device_desc: "device: XLA_GPU device"
# ]
# Using TensorFlow backend.
# 2019-09-12 07:59:30,310 INFO -------------------- Start --------------------
# 2019-09-12 07:59:30,311 INFO Working directory: /mnt/data/git/cardio.
# 2019-09-12 07:59:30,311 INFO Log file: ./logs/3D/downsampleZ/1_1_1_1.log
# 2019-09-12 07:59:30,312 INFO config saved:
#  {
#     "ACTIVATION": "elu",
#     "ARCHITECTURE": "3D",
#     "AUGMENT": false,
#     "AUGMENT_GRID": true,
#     "BATCHSIZE": 8,
#     "BATCH_NORMALISATION": true,
#     "CONFIG_PATH": "reports/configs/3D/downsampleZ/1_1_1_1/2019-09-12_07_59",
#     "DATASET": "tetra",
#     "DECAY": 0.0,
#     "DIM": [
#         16,
#         224,
#         224
#     ],
#     "DROPOUT_L1_L2": 0.3,
#     "DROPOUT_L3_L4": 0.4,
#     "DROPOUT_L5": 0.5,
#     "EPOCHS": 150,
#     "EPOCHS_BETWEEN_CHECKPOINTS": 5,
#     "EPSILON": 1e-08,
#     "EXPERIMENT": "3D/downsampleZ/1_1_1_1",
#     "FOLDS": 4,
#     "GENERATOR_WORKER": 8,
#     "HISTORY_PATH": "reports/history/3D/downsampleZ/1_1_1_1/2019-09-12_07_59",
#     "IMG_CHANNELS": 1,
#     "INITIAL_EPOCH": 0,
#     "LEARNING_RATE": 0.001,
#     "LOSS_FUNCTION": "bce_dice_jac_loss",
#     "MASK_CLASSES": 4,
#     "MASK_VALUES": [
#         0,
#         1,
#         2,
#         3
#     ],
#     "MODEL_PATH": "models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59",
#     "MONITOR_FUNCTION": "val_dice_coef_labels",
#     "MONITOR_MODE": "max",
#     "OPTIMIZER": "Adam",
#     "RESAMPLE": false,
#     "SHUFFLE": true,
#     "SPACING": [
#         8,
#         1.0,
#         1.0
#     ],
#     "TENSORBOARD_LOG_DIR": "reports/tensorboard_logs/3D/downsampleZ/1_1_1_1/2019-09-12_07_59",
#     "TEST_PATH": "data/raw/tetra/3D/test/",
#     "TRAIN_PATH": "data/raw/tetra/3D/train/",
#     "VAL_PATH": "data/raw/tetra/3D/val/"
# }
# 2019-09-12 07:59:31,320 ERROR Exception in callback functools.partial(<function wrap.<locals>.null_wrapper at 0x7f55d9709ea0>)
# Traceback (most recent call last):
#   File "/home/sven/anaconda3/envs/dl/lib/python3.6/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/home/sven/anaconda3/envs/dl/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sven/anaconda3/envs/dl/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 314, in advance_eventloop
#     eventloop(self)
# TypeError: 'NoneType' object is not callable

# %%
#from src.models.Isensee2017 import isensee2017_model
#from src.data.isensee_generator import DataGenerator
#model = isensee2017_model(input_shape=(1,224, 224, 16), loss_function=LOSS_FUNCTION, metrics=metrics)
#plot_model(model, to_file='reports/temp_model.png', show_shapes=True)
#model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1, 224, 224,  0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 16, 224, 224, 448         input_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_1 (Insta (None, 16, 224, 224, 32          conv3d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 16, 224, 224, 0           instance_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 16, 224, 224, 6928        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_2 (Insta (None, 16, 224, 224, 32          conv3d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 224, 224, 0           instance_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_1 (SpatialDro (None, 16, 224, 224, 0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 16, 224, 224, 6928        spatial_dropout3d_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_3 (Insta (None, 16, 224, 224, 32          conv3d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 16, 224, 224, 0           instance_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 224, 224, 0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 32, 112, 112, 13856       add_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_4 (Insta (None, 32, 112, 112, 16          conv3d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 112, 112, 0           instance_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 32, 112, 112, 27680       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_5 (Insta (None, 32, 112, 112, 16          conv3d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 112, 112, 0           instance_normalization_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_2 (SpatialDro (None, 32, 112, 112, 0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 112, 112, 27680       spatial_dropout3d_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_6 (Insta (None, 32, 112, 112, 16          conv3d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 112, 112, 0           instance_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 112, 112, 0           leaky_re_lu_4[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 64, 56, 56, 4 55360       add_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_7 (Insta (None, 64, 56, 56, 4 8           conv3d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 64, 56, 56, 4 0           instance_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 64, 56, 56, 4 110656      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 64, 56, 56, 4 8           conv3d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 56, 56, 4 0           instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_3 (SpatialDro (None, 64, 56, 56, 4 0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 64, 56, 56, 4 110656      spatial_dropout3d_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 64, 56, 56, 4 8           conv3d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64, 56, 56, 4 0           instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 56, 56, 4 0           leaky_re_lu_7[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 128, 28, 28,  221312      add_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 128, 28, 28,  4           conv3d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 128, 28, 28,  0           instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 128, 28, 28,  442496      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 128, 28, 28,  4           conv3d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 128, 28, 28,  0           instance_normalization_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_4 (SpatialDro (None, 128, 28, 28,  0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 128, 28, 28,  442496      spatial_dropout3d_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 128, 28, 28,  4           conv3d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 128, 28, 28,  0           instance_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 28, 28,  0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 256, 14, 14,  884992      add_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 256, 14, 14,  2           conv3d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 256, 14, 14,  0           instance_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 256, 14, 14,  1769728     leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_14 (Inst (None, 256, 14, 14,  2           conv3d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 14, 14,  0           instance_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout3d_5 (SpatialDro (None, 256, 14, 14,  0           leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 256, 14, 14,  1769728     spatial_dropout3d_5[0][0]
# __________________________________________________________________________________________________
# instance_normalization_15 (Inst (None, 256, 14, 14,  2           conv3d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 256, 14, 14,  0           instance_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 14, 14,  0           leaky_re_lu_13[0][0]
#                                                                  leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 256, 28, 28,  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 128, 28, 28,  884864      up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_16 (Inst (None, 128, 28, 28,  4           conv3d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128, 28, 28,  0           instance_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 28, 28,  0           add_4[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 128, 28, 28,  884864      concatenate_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_17 (Inst (None, 128, 28, 28,  4           conv3d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 128, 28, 28,  0           instance_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 128, 28, 28,  16512       leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# instance_normalization_18 (Inst (None, 128, 28, 28,  4           conv3d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 128, 28, 28,  0           instance_normalization_18[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 128, 56, 56,  0           leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 64, 56, 56, 4 221248      up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_19 (Inst (None, 64, 56, 56, 4 8           conv3d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 64, 56, 56, 4 0           instance_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 56, 56,  0           add_3[0][0]
#                                                                  leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 64, 56, 56, 4 221248      concatenate_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_20 (Inst (None, 64, 56, 56, 4 8           conv3d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 64, 56, 56, 4 0           instance_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 64, 56, 56, 4 4160        leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# instance_normalization_21 (Inst (None, 64, 56, 56, 4 8           conv3d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 64, 56, 56, 4 0           instance_normalization_21[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 64, 112, 112, 0           leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 32, 112, 112, 55328       up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_22 (Inst (None, 32, 112, 112, 16          conv3d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 32, 112, 112, 0           instance_normalization_22[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 112, 112, 0           add_2[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 32, 112, 112, 55328       concatenate_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_23 (Inst (None, 32, 112, 112, 16          conv3d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 32, 112, 112, 0           instance_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 32, 112, 112, 1056        leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# instance_normalization_24 (Inst (None, 32, 112, 112, 16          conv3d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 32, 112, 112, 0           instance_normalization_24[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 32, 224, 224, 0           leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 16, 224, 224, 13840       up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_25 (Inst (None, 16, 224, 224, 32          conv3d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 16, 224, 224, 0           instance_normalization_25[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 224, 224, 0           add_1[0][0]
#                                                                  leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 16, 224, 224, 13840       concatenate_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_26 (Inst (None, 16, 224, 224, 32          conv3d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 16, 224, 224, 0           instance_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 4, 56, 56, 4) 260         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 16, 224, 224, 272         leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_5 (UpSampling3D)  (None, 4, 112, 112,  0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 4, 112, 112,  132         leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# instance_normalization_27 (Inst (None, 16, 224, 224, 32          conv3d_29[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 112, 112,  0           up_sampling3d_5[0][0]
#                                                                  conv3d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 16, 224, 224, 0           instance_normalization_27[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_6 (UpSampling3D)  (None, 4, 224, 224,  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 4, 224, 224,  68          leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 224, 224,  0           up_sampling3d_6[0][0]
#                                                                  conv3d_30[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4, 224, 224,  0           add_7[0][0]
# ==================================================================================================
# Total params: 8,264,330
# Trainable params: 8,264,330
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Get training, val and test-files

# %%
"""
2D special
# load only slices from the lower, middle or upper part
X_train, Y_train = get_samples(path=TRAIN_PATH, samples=0, part='all', no_patients = 0, preprocessed=False)
X_val, Y_val = get_samples(path=VAL_PATH, samples=0, part='all', no_patients = 0, preprocessed=False)
X_test, Y_test = get_samples(path=TEST_PATH, samples=0, part='all', no_patients = 0, preprocessed=False)
"""

x_train, y_train = get_img_msk_files_from_split_dir(config['TRAIN_PATH'])
x_val, y_val = get_img_msk_files_from_split_dir(config['VAL_PATH'])
x_test, y_test = get_img_msk_files_from_split_dir(config['TEST_PATH'])

logging.info('x_train files: {}, y_train files: {}'.format(len(x_train), len(y_train)))
logging.info('x_val files: {}, y_val files: {}'.format(len(x_val), len(y_val)))
logging.info('x_test files: {}, y_test files: {}'.format(len(x_test), len(y_test)))
# Out:
# 2019-09-12 07:59:38,763 INFO x_train files: 754, y_train files: 754
# 2019-09-12 07:59:38,764 INFO x_val files: 130, y_val files: 130
# 2019-09-12 07:59:38,764 INFO x_test files: 126, y_test files: 126

# %% [markdown]
# ## Create Datagenerator

# %%
# create a batch generator
batch_generator = DataGenerator(x_train, y_train, config=config)
config['AUGMENT_GRID'] = False # make sure no augmentation will be applied to the evaluation data
validation_generator = DataGenerator(x_val, y_val , config=config)
test_generator = DataGenerator(x_test, y_test, config=config)
# Out:
# 2019-09-12 07:59:40,862 INFO Create DataGenerator
# 2019-09-12 07:59:40,867 INFO Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 8
#  Scaler: MinMax
#  Images: 754
#  Augment_grid: True
#  Thread workers: 8
# 2019-09-12 07:59:40,868 INFO No augmentation
# 2019-09-12 07:59:40,869 INFO Create DataGenerator
# 2019-09-12 07:59:40,870 INFO Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 8
#  Scaler: MinMax
#  Images: 130
#  Augment_grid: False
#  Thread workers: 8
# 2019-09-12 07:59:40,870 INFO No augmentation
# 2019-09-12 07:59:40,871 INFO Create DataGenerator
# 2019-09-12 07:59:40,872 INFO Datagenerator created with:
#  shape: [16, 224, 224]
#  batchsize: 8
#  Scaler: MinMax
#  Images: 126
#  Augment_grid: False
#  Thread workers: 8
# 2019-09-12 07:59:40,872 INFO No augmentation

# %% [markdown]
# ## Visualize one batch

# %%
# Select batch generator output
x = ''
y = ''
@interact
def select_batch(batch = (0,len(batch_generator), 1)):
    global x, y
    x, y = batch_generator.__getitem__(batch)
    print(x.shape)
# Out:
# interactive(children=(IntSlider(value=47, description='batch', max=94), Output()), _dom_classes=('widget-inter…

# %%
@interact
def select_image_in_batch(im = (0,config['BATCHSIZE']- 1, 1)):
    global x, y
    # define a different logging level to make the generator steps visible
    logging.getLogger().setLevel(logging.INFO)
    # hack to work with channel first
    #x = np.swapaxes(x, 1, -1)
    #y = np.swapaxes(y, 1, -1)
    show_2D_or_3D(x[im], y[im])
    plt.show()
# Out:
# interactive(children=(IntSlider(value=3, description='im', max=7), Output()), _dom_classes=('widget-interact',…

# %%
@interact
def interact_load_pretrained_model(config_file=glob.glob('reports/configs/{}/**/**/*.json'.format(config.get('ARCHITECTURE', '2D')), recursive=False), load=False):
    """
    load past config for model training 
    """
    # load config with all params into global namespace
    if load:
        with open(config_file, encoding='utf-8') as data_file:
            config = json.loads(data_file.read())
        #globals()['MODEL_PATH'] = config['MODEL_PATH']
        logging.info('Experiment: {}'.format(config['EXPERIMENT']))
        logging.info('config:\n {}'.format(json.dumps(config, indent=4, sort_keys=True)))
    
        try:
            # load model
            globals()['model'] = load_pretrained_model(config, metrics)
            model.summary()
        except Exception as e:
            logging.error(str(e))
# Out:
# interactive(children=(Dropdown(description='config_file', options=('reports/configs/3D/isensee_resampleZ8/2019…

# %% [markdown]
# ## Create Model

# %%
# create model

logging.info('Create model')
model = get_model(config, metrics)
model.summary()
# Out:
# 2019-09-12 08:00:03,176 INFO Create model
# 2019-09-12 08:00:04,984 INFO Optimizer: Adam
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16, 224, 224, 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 16, 224, 224, 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 224, 224, 64          conv3d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 224, 224, 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 16, 224, 224, 6928        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 224, 224, 64          conv3d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 16, 112, 112, 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 16, 112, 112, 13856       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 112, 112, 128         conv3d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 112, 112, 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 16, 112, 112, 27680       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 112, 112, 128         conv3d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 16, 56, 56, 3 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 16, 56, 56, 6 55360       max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 56, 56, 6 256         conv3d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 56, 56, 6 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 16, 56, 56, 6 110656      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 56, 56, 6 256         conv3d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 16, 28, 28, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 16, 28, 28, 1 221312      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 28, 28, 1 512         conv3d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 28, 28, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 16, 28, 28, 1 442496      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 28, 28, 1 512         conv3d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 16, 14, 14, 1 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 16, 14, 14, 2 884992      max_pooling3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 14, 14, 2 1024        conv3d_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 14, 14, 2 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 16, 14, 14, 2 1769728     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 14, 14, 2 1024        conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 16, 28, 28, 1 262272      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 28, 28, 2 0           conv3d_transpose_1[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 28, 28, 1 884864      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 28, 28, 1 512         conv3d_11[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 28, 28, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 16, 28, 28, 1 442496      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 28, 28, 1 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 16, 56, 56, 6 65600       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 56, 56, 1 0           conv3d_transpose_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 16, 56, 56, 6 221248      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 56, 56, 6 256         conv3d_13[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 56, 56, 6 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 16, 56, 56, 6 110656      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 56, 56, 6 256         conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 16, 112, 112, 16416       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 112, 112, 0           conv3d_transpose_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 16, 112, 112, 55328       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 112, 112, 128         conv3d_15[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 112, 112, 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 16, 112, 112, 27680       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 112, 112, 128         conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_4 (Conv3DTrans (None, 16, 224, 224, 4112        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 224, 224, 0           conv3d_transpose_4[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 16, 224, 224, 13840       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 224, 224, 64          conv3d_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 224, 224, 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 16, 224, 224, 6928        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 224, 224, 64          conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 16, 224, 224, 68          batch_normalization_18[0][0]
# ==================================================================================================
# Total params: 5,650,852
# Trainable params: 5,647,908
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file=os.path.join(config.get('CONFIG_PATH'),'model.png'), show_shapes=True)

# %%
plot_model(model, to_file=os.path.join('reports/','temp_model.png'), show_shapes=True)

# %%
initial_epoch = 0
# training

# start a new main process for this training to free gpu memory afterwards
with tf.device(current_gpu):
    logging.info('Fit model, start trainings process')
    # fit model with trainingsgenerator
    results = model.fit_generator(
        generator=batch_generator,
        epochs=config['EPOCHS'],
        callbacks=get_callbacks(config, batch_generator, validation_generator),
        steps_per_epoch = len(batch_generator),
        validation_data=validation_generator,
        initial_epoch=initial_epoch,
        max_queue_size=20,
        workers=4,
        verbose=1)
# Out:
# 2019-09-12 08:00:52,595 INFO Fit model, start trainings process
# 2019-09-12 08:00:54,683 INFO feed 4 Tensorboard is ready
# Epoch 1/150
# 94/94 [==============================] - 204s 2s/step - loss: 0.3862 - dice_coef_labels: 0.0533 - dice_coef_myo: 0.0303 - dice_coef_lv: 0.0482 - dice_coef_rv: 0.0820 - val_loss: 1.6076 - val_dice_coef_labels: 0.0466 - val_dice_coef_myo: 0.0301 - val_dice_coef_lv: 0.0370 - val_dice_coef_rv: 0.0755
# 2019-09-12 08:04:49,896 INFO Saved model to disk: models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59
# Epoch 00001: val_dice_coef_labels improved from -inf to 0.04656, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 2/150
# 94/94 [==============================] - 164s 2s/step - loss: 0.1861 - dice_coef_labels: 0.0848 - dice_coef_myo: 0.0510 - dice_coef_lv: 0.0776 - dice_coef_rv: 0.1270 - val_loss: 0.4464 - val_dice_coef_labels: 0.0901 - val_dice_coef_myo: 0.0555 - val_dice_coef_lv: 0.0794 - val_dice_coef_rv: 0.1392
#
# Epoch 00002: val_dice_coef_labels improved from 0.04656 to 0.09013, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 3/150
# 94/94 [==============================] - 171s 2s/step - loss: -0.0737 - dice_coef_labels: 0.1893 - dice_coef_myo: 0.1197 - dice_coef_lv: 0.1851 - dice_coef_rv: 0.2561 - val_loss: 0.0226 - val_dice_coef_labels: 0.1704 - val_dice_coef_myo: 0.0988 - val_dice_coef_lv: 0.1857 - val_dice_coef_rv: 0.2106
#
# Epoch 00003: val_dice_coef_labels improved from 0.09013 to 0.17039, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 4/150
# 94/94 [==============================] - 175s 2s/step - loss: -0.4244 - dice_coef_labels: 0.4623 - dice_coef_myo: 0.3325 - dice_coef_lv: 0.4821 - dice_coef_rv: 0.5335 - val_loss: -0.4605 - val_dice_coef_labels: 0.5245 - val_dice_coef_myo: 0.4179 - val_dice_coef_lv: 0.5989 - val_dice_coef_rv: 0.5305
#
# Epoch 00004: val_dice_coef_labels improved from 0.17039 to 0.52447, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 5/150
# 94/94 [==============================] - 175s 2s/step - loss: -0.6781 - dice_coef_labels: 0.6966 - dice_coef_myo: 0.5621 - dice_coef_lv: 0.7505 - dice_coef_rv: 0.7314 - val_loss: -0.5707 - val_dice_coef_labels: 0.6124 - val_dice_coef_myo: 0.5075 - val_dice_coef_lv: 0.6661 - val_dice_coef_rv: 0.6327
#
# Epoch 00005: val_dice_coef_labels improved from 0.52447 to 0.61237, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 6/150
# 94/94 [==============================] - 174s 2s/step - loss: -0.7586 - dice_coef_labels: 0.7741 - dice_coef_myo: 0.6561 - dice_coef_lv: 0.8347 - dice_coef_rv: 0.7937 - val_loss: -0.7047 - val_dice_coef_labels: 0.7211 - val_dice_coef_myo: 0.6447 - val_dice_coef_lv: 0.7576 - val_dice_coef_rv: 0.7377
#
# Epoch 00006: val_dice_coef_labels improved from 0.61237 to 0.72113, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 7/150
# 94/94 [==============================] - 179s 2s/step - loss: -0.7768 - dice_coef_labels: 0.7920 - dice_coef_myo: 0.6834 - dice_coef_lv: 0.8554 - dice_coef_rv: 0.8054 - val_loss: -0.7450 - val_dice_coef_labels: 0.7622 - val_dice_coef_myo: 0.6702 - val_dice_coef_lv: 0.8577 - val_dice_coef_rv: 0.7529
#
# Epoch 00007: val_dice_coef_labels improved from 0.72113 to 0.76220, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 8/150
# 94/94 [==============================] - 175s 2s/step - loss: -0.7891 - dice_coef_labels: 0.8039 - dice_coef_myo: 0.6979 - dice_coef_lv: 0.8698 - dice_coef_rv: 0.8142 - val_loss: -0.7888 - val_dice_coef_labels: 0.8037 - val_dice_coef_myo: 0.7231 - val_dice_coef_lv: 0.8892 - val_dice_coef_rv: 0.7952
#
# Epoch 00008: val_dice_coef_labels improved from 0.76220 to 0.80375, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 9/150
# 94/94 [==============================] - 179s 2s/step - loss: -0.8004 - dice_coef_labels: 0.8147 - dice_coef_myo: 0.7109 - dice_coef_lv: 0.8769 - dice_coef_rv: 0.8260 - val_loss: -0.7951 - val_dice_coef_labels: 0.8093 - val_dice_coef_myo: 0.7345 - val_dice_coef_lv: 0.8908 - val_dice_coef_rv: 0.7997
#
# Epoch 00009: val_dice_coef_labels improved from 0.80375 to 0.80934, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 10/150
# 94/94 [==============================] - 175s 2s/step - loss: -0.8050 - dice_coef_labels: 0.8193 - dice_coef_myo: 0.7189 - dice_coef_lv: 0.8822 - dice_coef_rv: 0.8282 - val_loss: -0.8086 - val_dice_coef_labels: 0.8220 - val_dice_coef_myo: 0.7564 - val_dice_coef_lv: 0.9019 - val_dice_coef_rv: 0.8095
#
# Epoch 00010: val_dice_coef_labels improved from 0.80934 to 0.82205, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 11/150
# 94/94 [==============================] - 171s 2s/step - loss: -0.8143 - dice_coef_labels: 0.8280 - dice_coef_myo: 0.7290 - dice_coef_lv: 0.8870 - dice_coef_rv: 0.8387 - val_loss: -0.8139 - val_dice_coef_labels: 0.8274 - val_dice_coef_myo: 0.7497 - val_dice_coef_lv: 0.8930 - val_dice_coef_rv: 0.8251
#
# Epoch 00011: val_dice_coef_labels improved from 0.82205 to 0.82739, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 12/150
# 94/94 [==============================] - 181s 2s/step - loss: -0.8185 - dice_coef_labels: 0.8321 - dice_coef_myo: 0.7368 - dice_coef_lv: 0.8915 - dice_coef_rv: 0.8410 - val_loss: -0.7973 - val_dice_coef_labels: 0.8132 - val_dice_coef_myo: 0.7476 - val_dice_coef_lv: 0.8906 - val_dice_coef_rv: 0.8018
#
# Epoch 00012: val_dice_coef_labels did not improve from 0.82739
# Epoch 13/150
# 94/94 [==============================] - 182s 2s/step - loss: -0.8216 - dice_coef_labels: 0.8350 - dice_coef_myo: 0.7395 - dice_coef_lv: 0.8937 - dice_coef_rv: 0.8444 - val_loss: -0.8134 - val_dice_coef_labels: 0.8275 - val_dice_coef_myo: 0.7577 - val_dice_coef_lv: 0.9053 - val_dice_coef_rv: 0.8177
#
# Epoch 00013: val_dice_coef_labels improved from 0.82739 to 0.82754, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 14/150
# 94/94 [==============================] - 179s 2s/step - loss: -0.8276 - dice_coef_labels: 0.8405 - dice_coef_myo: 0.7442 - dice_coef_lv: 0.8974 - dice_coef_rv: 0.8509 - val_loss: -0.8169 - val_dice_coef_labels: 0.8298 - val_dice_coef_myo: 0.7593 - val_dice_coef_lv: 0.9067 - val_dice_coef_rv: 0.8205
#
# Epoch 00014: val_dice_coef_labels improved from 0.82754 to 0.82976, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 15/150
# 94/94 [==============================] - 176s 2s/step - loss: -0.8291 - dice_coef_labels: 0.8418 - dice_coef_myo: 0.7484 - dice_coef_lv: 0.8989 - dice_coef_rv: 0.8511 - val_loss: -0.8226 - val_dice_coef_labels: 0.8360 - val_dice_coef_myo: 0.7697 - val_dice_coef_lv: 0.9108 - val_dice_coef_rv: 0.8259
#
# Epoch 00015: val_dice_coef_labels improved from 0.82976 to 0.83601, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 16/150
# 94/94 [==============================] - 172s 2s/step - loss: -0.8312 - dice_coef_labels: 0.8439 - dice_coef_myo: 0.7490 - dice_coef_lv: 0.9010 - dice_coef_rv: 0.8540 - val_loss: -0.8217 - val_dice_coef_labels: 0.8353 - val_dice_coef_myo: 0.7743 - val_dice_coef_lv: 0.9106 - val_dice_coef_rv: 0.8248
#
# Epoch 00016: val_dice_coef_labels did not improve from 0.83601
# Epoch 17/150
# 94/94 [==============================] - 170s 2s/step - loss: -0.8335 - dice_coef_labels: 0.8460 - dice_coef_myo: 0.7526 - dice_coef_lv: 0.9009 - dice_coef_rv: 0.8565 - val_loss: -0.8194 - val_dice_coef_labels: 0.8333 - val_dice_coef_myo: 0.7492 - val_dice_coef_lv: 0.9104 - val_dice_coef_rv: 0.8283
#
# Epoch 00017: val_dice_coef_labels did not improve from 0.83601
# Epoch 18/150
# 94/94 [==============================] - 179s 2s/step - loss: -0.8378 - dice_coef_labels: 0.8499 - dice_coef_myo: 0.7553 - dice_coef_lv: 0.9027 - dice_coef_rv: 0.8620 - val_loss: -0.8213 - val_dice_coef_labels: 0.8347 - val_dice_coef_myo: 0.7706 - val_dice_coef_lv: 0.9096 - val_dice_coef_rv: 0.8238
#
# Epoch 00018: val_dice_coef_labels did not improve from 0.83601
# Epoch 19/150
# 94/94 [==============================] - 174s 2s/step - loss: -0.8389 - dice_coef_labels: 0.8509 - dice_coef_myo: 0.7586 - dice_coef_lv: 0.9046 - dice_coef_rv: 0.8616 - val_loss: -0.8193 - val_dice_coef_labels: 0.8326 - val_dice_coef_myo: 0.7675 - val_dice_coef_lv: 0.9121 - val_dice_coef_rv: 0.8188
#
# Epoch 00019: val_dice_coef_labels did not improve from 0.83601
# Epoch 20/150
# 94/94 [==============================] - 170s 2s/step - loss: -0.8418 - dice_coef_labels: 0.8536 - dice_coef_myo: 0.7619 - dice_coef_lv: 0.9063 - dice_coef_rv: 0.8647 - val_loss: -0.8271 - val_dice_coef_labels: 0.8400 - val_dice_coef_myo: 0.7776 - val_dice_coef_lv: 0.9148 - val_dice_coef_rv: 0.8284
#
# Epoch 00020: val_dice_coef_labels improved from 0.83601 to 0.83999, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 21/150
# 94/94 [==============================] - 162s 2s/step - loss: -0.8442 - dice_coef_labels: 0.8559 - dice_coef_myo: 0.7628 - dice_coef_lv: 0.9075 - dice_coef_rv: 0.8679 - val_loss: -0.8277 - val_dice_coef_labels: 0.8408 - val_dice_coef_myo: 0.7792 - val_dice_coef_lv: 0.9153 - val_dice_coef_rv: 0.8290
#
# Epoch 00021: val_dice_coef_labels improved from 0.83999 to 0.84077, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 22/150
# 94/94 [==============================] - 164s 2s/step - loss: -0.8432 - dice_coef_labels: 0.8549 - dice_coef_myo: 0.7643 - dice_coef_lv: 0.9077 - dice_coef_rv: 0.8651 - val_loss: -0.8286 - val_dice_coef_labels: 0.8421 - val_dice_coef_myo: 0.7822 - val_dice_coef_lv: 0.9160 - val_dice_coef_rv: 0.8307
#
# Epoch 00022: val_dice_coef_labels improved from 0.84077 to 0.84210, saving model to models/3D/downsampleZ/1_1_1_1/2019-09-12_07_59/checkpoint.h5
# Epoch 23/150
# 94/94 [==============================] - 163s 2s/step - loss: -0.8452 - dice_coef_labels: 0.8567 - dice_coef_myo: 0.7646 - dice_coef_lv: 0.9092 - dice_coef_rv: 0.8679 - val_loss: -0.8100 - val_dice_coef_labels: 0.8240 - val_dice_coef_myo: 0.7513 - val_dice_coef_lv: 0.9113 - val_dice_coef_rv: 0.8071
#
# Epoch 00023: val_dice_coef_labels did not improve from 0.84210
# Epoch 24/150
# 94/94 [==============================] - 165s 2s/step - loss: -0.8459 - dice_coef_labels: 0.8574 - dice_coef_myo: 0.7650 - dice_coef_lv: 0.9100 - dice_coef_rv: 0.8687 - val_loss: -0.8188 - val_dice_coef_labels: 0.8326 - val_dice_coef_myo: 0.7642 - val_dice_coef_lv: 0.9102 - val_dice_coef_rv: 0.8199
#
# Epoch 00024: val_dice_coef_labels did not improve from 0.84210
# Epoch 25/150
# 94/94 [==============================] - 162s 2s/step - loss: -0.8495 - dice_coef_labels: 0.8606 - dice_coef_myo: 0.7688 - dice_coef_lv: 0.9121 - dice_coef_rv: 0.8728 - val_loss: -0.8285 - val_dice_coef_labels: 0.8415 - val_dice_coef_myo: 0.7752 - val_dice_coef_lv: 0.9147 - val_dice_coef_rv: 0.8324
#
# Epoch 00025: val_dice_coef_labels did not improve from 0.84210
# Epoch 26/150
# 94/94 [==============================] - 161s 2s/step - loss: -0.8478 - dice_coef_labels: 0.8590 - dice_coef_myo: 0.7685 - dice_coef_lv: 0.9110 - dice_coef_rv: 0.8700 - val_loss: -0.8252 - val_dice_coef_labels: 0.8388 - val_dice_coef_myo: 0.7796 - val_dice_coef_lv: 0.9151 - val_dice_coef_rv: 0.8256
#
# Epoch 00026: val_dice_coef_labels did not improve from 0.84210
# Epoch 27/150
# 94/94 [==============================] - 164s 2s/step - loss: -0.8487 - dice_coef_labels: 0.8598 - dice_coef_myo: 0.7692 - dice_coef_lv: 0.9096 - dice_coef_rv: 0.8720 - val_loss: -0.8152 - val_dice_coef_labels: 0.8295 - val_dice_coef_myo: 0.7696 - val_dice_coef_lv: 0.9161 - val_dice_coef_rv: 0.8086
#
# Epoch 00027: val_dice_coef_labels did not improve from 0.84210
# Epoch 28/150
# 94/94 [==============================] - 166s 2s/step - loss: -0.8504 - dice_coef_labels: 0.8616 - dice_coef_myo: 0.7695 - dice_coef_lv: 0.9092 - dice_coef_rv: 0.8755 - val_loss: -0.8068 - val_dice_coef_labels: 0.8219 - val_dice_coef_myo: 0.7775 - val_dice_coef_lv: 0.9140 - val_dice_coef_rv: 0.7904
#
# Epoch 00028: val_dice_coef_labels did not improve from 0.84210
# Epoch 29/150
# 94/94 [==============================] - 167s 2s/step - loss: -0.8525 - dice_coef_labels: 0.8635 - dice_coef_myo: 0.7718 - dice_coef_lv: 0.9122 - dice_coef_rv: 0.8766 - val_loss: -0.8174 - val_dice_coef_labels: 0.8315 - val_dice_coef_myo: 0.7757 - val_dice_coef_lv: 0.9144 - val_dice_coef_rv: 0.8117
#
# Epoch 00029: val_dice_coef_labels did not improve from 0.84210
# Epoch 30/150
# 94/94 [==============================] - 163s 2s/step - loss: -0.8513 - dice_coef_labels: 0.8622 - dice_coef_myo: 0.7720 - dice_coef_lv: 0.9115 - dice_coef_rv: 0.8746 - val_loss: -0.8134 - val_dice_coef_labels: 0.8281 - val_dice_coef_myo: 0.7778 - val_dice_coef_lv: 0.9151 - val_dice_coef_rv: 0.8030
#
# Epoch 00030: val_dice_coef_labels did not improve from 0.84210
# Epoch 31/150
# 94/94 [==============================] - 157s 2s/step - loss: -0.8536 - dice_coef_labels: 0.8644 - dice_coef_myo: 0.7718 - dice_coef_lv: 0.9123 - dice_coef_rv: 0.8784 - val_loss: -0.8157 - val_dice_coef_labels: 0.8302 - val_dice_coef_myo: 0.7790 - val_dice_coef_lv: 0.9156 - val_dice_coef_rv: 0.8080
#
# Epoch 00031: val_dice_coef_labels did not improve from 0.84210
# Epoch 32/150
# 94/94 [==============================] - 162s 2s/step - loss: -0.8532 - dice_coef_labels: 0.8641 - dice_coef_myo: 0.7726 - dice_coef_lv: 0.9115 - dice_coef_rv: 0.8780 - val_loss: -0.8180 - val_dice_coef_labels: 0.8322 - val_dice_coef_myo: 0.7807 - val_dice_coef_lv: 0.9156 - val_dice_coef_rv: 0.8111
#
# Epoch 00032: val_dice_coef_labels did not improve from 0.84210
# Epoch 00032: early stopping

# %% [markdown]
# ## Write trainings history to disk

# %%
logging.info(results.history)
df_history = pd.DataFrame(results.history)

df_history.to_csv(os.path.join('reports/history/3D_unet/', config['EXPERIMENT'] + '.csv'))
df_history.plot()

# %% [markdown]
# ## Save model to disk

# %%
from src.utils.utils_io import ensure_dir
model_json = model.to_json()
model_path = os.path.join('models/', config['EXPERIMENT'])
ensure_dir(model_path)
with open(os.path.join(model_path, 'model.json'), "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
name = 'weights_e-{0}_val_loss-{1}.h5'.format(config['EXPERIMENT'], '01')
model.save_weights(os.path.join(model_path, name))
logging.info("Saved model to disk: {}".format(model_path))

# %% [markdown]
# ## Calculate metrics

# %%
# predict for all batches
from medpy.metric.binary import hd, dc,jc,precision,recall
import numpy as np
gt_ = []
pred_ = []
img_ = []
n_batches = len(test_generator)
#n_batches = 2
logging.info('load and predict {} batches'.format(n_batches))
#with tf.device(current_gpu):
#    pred = model.predict_generator(batch_generator, steps = len(batch_generator))
#
#gt_ = [gt_.extend(batch[1]) for batch in batch_generator]
    


for idx,batch in enumerate(test_generator):
    if idx <= n_batches:
        with tf.device(current_gpu):
            img_.extend(batch[0])
            pred_.extend(((model.predict_on_batch(batch[0]))>=0.5).astype(np.bool))
        gt_.extend(batch[1])
    else:
        break

# reshape
gt = np.array(gt_)
pred = np.array(pred_)

logging.info('gt shape: {}'.format(gt.shape))
logging.info('pred shape: {}'.format(pred.shape))
del gt_
del pred_

# %%
# calc medpy scores
jaccard_coef = jc(pred, gt)
dice_score = dc(pred, gt)
precision_score = precision(pred, gt)
recall_score = recall(pred, gt)

logging.info('jac: {}'.format(jaccard_coef))
logging.info('dice: {}'.format(dice_score))
logging.info('prec: {}'.format(precision_score))
logging.info('recall: {}'.format(recall_score))

# %%
# calc IOU per channel
for c in range(pred.shape[-1]):
    pred_ = pred[...,c]
    gt_ = gt[...,c]
    # calc medpy scores
    jaccard_coef = jc(pred_, gt_)
    dice_score = dc(pred_, gt_)
    precision_score = precision(pred_, gt_)
    recall_score = recall(pred_, gt_)

    logging.info('jac: {}'.format(jaccard_coef))
    logging.info('dice: {}'.format(dice_score))
    logging.info('prec: {}'.format(precision_score))
    logging.info('recall: {}'.format(recall_score))

# %%
from src.utils.my_metrics import jaccard_coef, jaccard_coef_background, jaccard_coef_rv, jaccard_coef_lv, jaccard_coef_myo, bce_dice_iou_loss, weighted_categorical_crossentropy, cce_dice_loss, weighted_cce_dice_coef

# %%
# calc IOU per channel
for c in range(pred.shape[-1]):
    pred_ = pred[...,c]
    gt_ = gt[...,c]
    # calc medpy scores
    jaccard_coef = jc(pred_, gt_)
    dice_score = dc(pred_, gt_)
    precision_score = precision(pred_, gt_)
    recall_score = recall(pred_, gt_)

    logging.info('jac: {}'.format(jaccard_coef))
    logging.info('dice: {}'.format(dice_score))
    logging.info('prec: {}'.format(precision_score))
    logging.info('recall: {}'.format(recall_score))

# %%
from src.visualization.visualize import plot_3d_vol

# %%
plot_3d_vol(img_[0], gt[0])

# %%
plot_3d_vol(img_[0], pred[0])

# %%
print(pred_[0].shape)

# %%
plot_3d_vol(pred_[0])

# %%
pred[0].max()
