# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.notebook_imports import *
from pyforest import *


# define GPU id to use
# 0 = 1080 Bus ID 2
# 1 = Titan Bus ID 131
# 2 = Titan Bus ID 132
GPU_IDS = '0,1'
current_gpu = choose_gpu_by_id(GPU_IDS)
print(current_gpu)

# jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# import own modules and utils
from src.utils.utils_io import Console_and_file_logger, ensure_dir, init_config
import src.utils.my_metrics as metr
from src.models.train_model import train_kfolded
# train kfolded data, start each fold manually to improve speed
from src.data.dataset import get_kfolded_data, create_acdc_dataframe_for_cv

# define experiment name for report, model and log paths + filenames
EXPERIMENT = '2D/close_gap2/acdc_plus2'
now = datetime.datetime.now()

# image params
DIM = [224, 224]
IMG_WIDTH = 224
IMG_HEIGHT = 224
# Grayscale images
IMG_CHANNELS = 1
# RV = 1 = Y[...,0] 
# Myo = 2 = Y[...,1] 
# LV = 3 = Y[...,2]
MASK_VALUES = [0, 1, 2, 3]  
MASK_CLASSES = len(MASK_VALUES)
AUGMENT = False
SHUFFLE = True
AUGMENT_GRID = True
RESAMPLE = False
SPACING_X = 1.00
SPACING_Y = 1.00
SCALER = 'MinMax'


# path params
DATASET = 'tetra'  # 'acdc' # or 'tetra'
DATA_ROOT = 'data/raw/tetra/2D/'
TRAIN_PATH = 'data/raw/tetra/2D/train/'
VAL_PATH = 'data/raw/tetra/2D/val/'
TEST_PATH = 'data/raw/tetra/2D/test/'

MODEL_PATH = os.path.join(os.path.join('models', EXPERIMENT), str(now.strftime("%Y-%m-%d_%H_%M")))
TENSORBOARD_LOG_DIR = os.path.join(os.path.join('reports/tensorboard_logs', EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))
CONFIG_PATH = os.path.join(os.path.join('reports/configs/',EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))
HISTORY_PATH = os.path.join(os.path.join('reports/history/',EXPERIMENT),str(now.strftime("%Y-%m-%d_%H_%M")))

# training params
ARCHITECTURE = '2D'
seed = 42
BATCHSIZE =  64 # 32, 64, 16, 1
INITIAL_EPOCH = 0
EPOCHS = 150
FOLDS = 4
EPOCHS_BETWEEN_CHECKPOINTS = 5
MONITOR_FUNCTION = 'val_dice_coef_labels'
MONITOR_MODE = 'max'

# Network params
OPTIMIZER = 'Adam'  # adam, sgd, softmax # https://keras.io/optimizers/
ACTIVATION = 'elu'  # 'elu' --> works well with binary_crossentropy and bce_dice_loss, relu does not work, it clips negative values, bse does return negative values
LEARNING_RATE = 0.001
DECAY = 0.0
EPSILON = 1e-08
DROPOUT_L1_L2 = 0.3 # best with 0.3 - 0.5
DROPOUT_L3_L4 = 0.4
DROPOUT_L5 = 0.5
BATCH_NORMALISATION = True


LOSS_FUNCTION = metr.bce_dice_jac_loss  # 'binary_crossentropy'--> 91 IOU, bce_dice_loss --> 94 IOU
#LOSS_FUNCTION = metr.weighted_cce_dice_coef([1,5,5,3])
#LOSS_FUNCTION = keras.losses.categorical_crossentropy
#LOSS_FUNCTION = metr.weighted_categorical_crossentropy([1,5,10,3])
#LOSS_FUNCTION = keras.losses.binary_crossentropy
metrics = [
    metr.dice_coef_labels,
    metr.dice_coef_myo,
    metr.dice_coef_lv,
    metr.dice_coef_rv,
]

# make sure logging directories are available
Console_and_file_logger(EXPERIMENT, logging.INFO)


# Define a config for param injection,
# save a serialized version, 
# make sure all paths exist
config = init_config(locals(), False)


# define a Tensorflow config
#tf_config = tf.ConfigProto()
#tf_config=tf.ConfigProto(
#      allow_soft_placement=True, log_device_placement=True)
#tf_config.gpu_options.allow_growth = True
#tf_session = tf.Session(config=tf_config)
#tf.keras.backend.set_session(tf_session)
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/data/git/cardio
# Using TensorFlow backend.
# 2019-10-29 20:44:00,586 INFO -------------------- Start --------------------
# 2019-10-29 20:44:00,586 INFO Working directory: /mnt/data/git/cardio.
# 2019-10-29 20:44:00,587 INFO Log file: ./logs/2D/close_gap2/acdc_plus2.log
# ['gpu(0)', 'gpu(1)']

# %% [markdown]
# ## Train a model on ACDC data & n patients from the GCN data, define the generalisation gap

# %%
# used for Finetuning a model
def get_n_patients(df, n=1, fold=0):
    # make random.choice idempotent
    np.random.seed(42)
    # select random patients
    patients = np.random.choice(sorted(df['patient'].unique()), size=n)
    logging.info('Added patients: {} from the GCN dataset'.format(patients))
    # filter data frame by fold and by random selected patients ids, make sure to make a copy to avoid side effects
    df_temp = df[(df['fold'] == fold) & (df['patient'].isin(patients))].copy()
    # make sure all selected images will be used during training train images
    # train_kfolded will only use images with modality == train, override the modality for all selected patients/rows
    df_temp.loc[:,'modality'] = 'train'
    df_temp.reset_index(inplace=True)
    return df_temp

fold = 0
number_of_gcn_patients = 2

# load ACDC split
kfold_data_dir_acdc = 'reports/kfolds_data/2D/unet_acdc_spacing1_batch32_drop04_batchnorm_minmax_kfold/'
df_folds_acdc = pd.read_csv(os.path.join(kfold_data_dir_acdc, 'df_kfold_acdc.csv'))


# load GCN split
kfold_data_dir_gcn = 'reports/kfolds_data/2D/unet_tetra_spacing1_batch32_drop04_batchnorm_minmax_kfold4'
df_folds_gcn = pd.read_csv(os.path.join(kfold_data_dir_gcn, 'df_kfold.csv'))


extend = get_n_patients(df_folds_gcn, number_of_gcn_patients)
df_folds = pd.concat([df_folds_acdc, extend], sort=False)
df_fold = df_folds[df_folds['fold'] == fold]
config['GCN_PATIENTS'] = sorted(extend['patient'].unique())
config['GCN_IMAGES'] = len(extend)

train_kfolded(config, metrics, df_fold)
# Out:
# 2019-10-29 20:44:08,304 INFO Added patients: ['0275-D8RUZJ8N-2006-09-22' '0547-RHQMXMC7-2005-11-28'] from the GCN dataset
# 2019-10-29 20:44:08,315 INFO Fold: 0
# 2019-10-29 20:44:08,316 INFO train images: 1550
# 2019-10-29 20:44:08,316 INFO train masks: 1550
# 2019-10-29 20:44:08,316 INFO test images: 474
# 2019-10-29 20:44:08,317 INFO test masks: 474
# 2019-10-29 20:44:08,317 INFO Create DataGenerator
# 2019-10-29 20:44:08,322 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 64
#  Scaler: MinMax
#  Images: 1550
#  Augment_grid: True
#  Thread workers: 64
# 2019-10-29 20:44:08,322 INFO No augmentation
# 2019-10-29 20:44:08,322 INFO Create DataGenerator
# 2019-10-29 20:44:08,324 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 64
#  Scaler: MinMax
#  Images: 474
#  Augment_grid: False
#  Thread workers: 64
# 2019-10-29 20:44:08,324 INFO No augmentation
# 2019-10-29 20:44:12,239 INFO Optimizer: Adam
# 2019-10-29 20:44:12,387 INFO selected patients: ['0116-5CXHN75U-2006-08-02'] from: 151
# 2019-10-29 20:44:12,392 INFO Create DataGenerator
# 2019-10-29 20:44:12,392 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 2
#  Scaler: MinMax
#  Images: 15
#  Augment_grid: False
#  Thread workers: 2
# 2019-10-29 20:44:12,393 INFO No augmentation
# 2019-10-29 20:44:12,433 INFO selected patients: ['0514-Q0QN3J15-2005-05-12'] from: 25
# 2019-10-29 20:44:12,437 INFO Create DataGenerator
# 2019-10-29 20:44:12,438 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 2
#  Scaler: MinMax
#  Images: 15
#  Augment_grid: False
#  Thread workers: 2
# 2019-10-29 20:44:12,438 INFO No augmentation
# 2019-10-29 20:44:12,525 INFO selected patients: ['0116-5CXHN75U-2006-08-02'] from: 151
# 2019-10-29 20:44:12,530 INFO Create DataGenerator
# 2019-10-29 20:44:12,531 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 2
#  Scaler: MinMax
#  Images: 35
#  Augment_grid: False
#  Thread workers: 2
# 2019-10-29 20:44:12,531 INFO No augmentation
# 2019-10-29 20:44:12,551 INFO selected patients: ['0514-Q0QN3J15-2005-05-12'] from: 25
# 2019-10-29 20:44:12,555 INFO Create DataGenerator
# 2019-10-29 20:44:12,555 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 2
#  Scaler: MinMax
#  Images: 45
#  Augment_grid: False
#  Thread workers: 2
# 2019-10-29 20:44:12,556 INFO No augmentation
# 2019-10-29 20:44:12,656 INFO selected patients: ['0116-5CXHN75U-2006-08-02'] from: 151
# 2019-10-29 20:44:12,661 INFO Create DataGenerator
# 2019-10-29 20:44:12,662 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 2
#  Scaler: MinMax
#  Images: 20
#  Augment_grid: False
#  Thread workers: 2
# 2019-10-29 20:44:12,662 INFO No augmentation
# 2019-10-29 20:44:12,682 INFO selected patients: ['0514-Q0QN3J15-2005-05-12'] from: 25
# 2019-10-29 20:44:12,686 INFO Create DataGenerator
# 2019-10-29 20:44:12,686 INFO Datagenerator created with:
#  shape: [224, 224]
#  batchsize: 2
#  Scaler: MinMax
#  Images: 20
#  Augment_grid: False
#  Thread workers: 2
# 2019-10-29 20:44:12,687 INFO No augmentation
# 2019-10-29 20:44:12,971 INFO feed 4 Tensorboard is ready
# 2019-10-29 20:44:15,606 INFO Fit model
# Epoch 1/150
# 24/24 [==============================] - 16s 674ms/step - loss: 0.4606 - dice_coef_labels: 0.0483 - dice_coef_myo: 0.0417 - dice_coef_lv: 0.0503 - dice_coef_rv: 0.0532 - val_loss: 0.5997 - val_dice_coef_labels: 0.0543 - val_dice_coef_myo: 0.0401 - val_dice_coef_lv: 0.0831 - val_dice_coef_rv: 0.0549
# 2019-10-29 20:44:39,921 INFO Saved model to disk: models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0
# Epoch 00001: loss improved from inf to 0.46059, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 2/150
# 24/24 [==============================] - 6s 230ms/step - loss: 0.3850 - dice_coef_labels: 0.0630 - dice_coef_myo: 0.0578 - dice_coef_lv: 0.0633 - dice_coef_rv: 0.0683 - val_loss: 0.4291 - val_dice_coef_labels: 0.0631 - val_dice_coef_myo: 0.0601 - val_dice_coef_lv: 0.0677 - val_dice_coef_rv: 0.0618
#
# Epoch 00002: loss improved from 0.46059 to 0.38503, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 3/150
# 24/24 [==============================] - 5s 225ms/step - loss: 0.3374 - dice_coef_labels: 0.0695 - dice_coef_myo: 0.0640 - dice_coef_lv: 0.0694 - dice_coef_rv: 0.0755 - val_loss: 0.3239 - val_dice_coef_labels: 0.0684 - val_dice_coef_myo: 0.0737 - val_dice_coef_lv: 0.0691 - val_dice_coef_rv: 0.0625
#
# Epoch 00003: loss improved from 0.38503 to 0.33743, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 4/150
# 24/24 [==============================] - 10s 397ms/step - loss: 0.2888 - dice_coef_labels: 0.0766 - dice_coef_myo: 0.0704 - dice_coef_lv: 0.0766 - dice_coef_rv: 0.0835 - val_loss: 0.2660 - val_dice_coef_labels: 0.0775 - val_dice_coef_myo: 0.0840 - val_dice_coef_lv: 0.0770 - val_dice_coef_rv: 0.0719
#
# Epoch 00004: loss improved from 0.33743 to 0.28885, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 5/150
# 24/24 [==============================] - 6s 233ms/step - loss: 0.2362 - dice_coef_labels: 0.0848 - dice_coef_myo: 0.0784 - dice_coef_lv: 0.0835 - dice_coef_rv: 0.0932 - val_loss: 0.1925 - val_dice_coef_labels: 0.0888 - val_dice_coef_myo: 0.0964 - val_dice_coef_lv: 0.0868 - val_dice_coef_rv: 0.0839
#
# Epoch 00005: loss improved from 0.28885 to 0.23615, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 6/150
# 24/24 [==============================] - 6s 231ms/step - loss: 0.1731 - dice_coef_labels: 0.0991 - dice_coef_myo: 0.0914 - dice_coef_lv: 0.0966 - dice_coef_rv: 0.1104 - val_loss: 0.2063 - val_dice_coef_labels: 0.0994 - val_dice_coef_myo: 0.0956 - val_dice_coef_lv: 0.0898 - val_dice_coef_rv: 0.1148
#
# Epoch 00006: loss improved from 0.23615 to 0.17311, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 7/150
# 24/24 [==============================] - 6s 238ms/step - loss: 0.1107 - dice_coef_labels: 0.1148 - dice_coef_myo: 0.1075 - dice_coef_lv: 0.1107 - dice_coef_rv: 0.1276 - val_loss: 0.1530 - val_dice_coef_labels: 0.1029 - val_dice_coef_myo: 0.1106 - val_dice_coef_lv: 0.0964 - val_dice_coef_rv: 0.1022
#
# Epoch 00007: loss improved from 0.17311 to 0.11066, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 8/150
# 24/24 [==============================] - 6s 235ms/step - loss: 0.0414 - dice_coef_labels: 0.1401 - dice_coef_myo: 0.1297 - dice_coef_lv: 0.1334 - dice_coef_rv: 0.1595 - val_loss: 0.1628 - val_dice_coef_labels: 0.1215 - val_dice_coef_myo: 0.1150 - val_dice_coef_lv: 0.1235 - val_dice_coef_rv: 0.1264
#
# Epoch 00008: loss improved from 0.11066 to 0.04138, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 9/150
# 24/24 [==============================] - 5s 227ms/step - loss: -0.0303 - dice_coef_labels: 0.1726 - dice_coef_myo: 0.1594 - dice_coef_lv: 0.1648 - dice_coef_rv: 0.1966 - val_loss: 0.0785 - val_dice_coef_labels: 0.1282 - val_dice_coef_myo: 0.1306 - val_dice_coef_lv: 0.1265 - val_dice_coef_rv: 0.1272
#
# Epoch 00009: loss improved from 0.04138 to -0.03032, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 10/150
# 24/24 [==============================] - 6s 233ms/step - loss: -0.1100 - dice_coef_labels: 0.2174 - dice_coef_myo: 0.2011 - dice_coef_lv: 0.2107 - dice_coef_rv: 0.2431 - val_loss: -0.0213 - val_dice_coef_labels: 0.1907 - val_dice_coef_myo: 0.1654 - val_dice_coef_lv: 0.2073 - val_dice_coef_rv: 0.2054
#
# Epoch 00010: loss improved from -0.03032 to -0.10998, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 11/150
# 24/24 [==============================] - 10s 401ms/step - loss: -0.2035 - dice_coef_labels: 0.2825 - dice_coef_myo: 0.2627 - dice_coef_lv: 0.2733 - dice_coef_rv: 0.3139 - val_loss: -0.1483 - val_dice_coef_labels: 0.2515 - val_dice_coef_myo: 0.2347 - val_dice_coef_lv: 0.2659 - val_dice_coef_rv: 0.2533
#
# Epoch 00011: loss improved from -0.10998 to -0.20353, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 12/150
# 24/24 [==============================] - 6s 234ms/step - loss: -0.3071 - dice_coef_labels: 0.3638 - dice_coef_myo: 0.3382 - dice_coef_lv: 0.3598 - dice_coef_rv: 0.3952 - val_loss: -0.2155 - val_dice_coef_labels: 0.2899 - val_dice_coef_myo: 0.3099 - val_dice_coef_lv: 0.3023 - val_dice_coef_rv: 0.2566
#
# Epoch 00012: loss improved from -0.20353 to -0.30706, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 13/150
# 24/24 [==============================] - 5s 226ms/step - loss: -0.4407 - dice_coef_labels: 0.4792 - dice_coef_myo: 0.4433 - dice_coef_lv: 0.4821 - dice_coef_rv: 0.5127 - val_loss: -0.1576 - val_dice_coef_labels: 0.2978 - val_dice_coef_myo: 0.2250 - val_dice_coef_lv: 0.4135 - val_dice_coef_rv: 0.3028
#
# Epoch 00013: loss improved from -0.30706 to -0.44067, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 14/150
# 24/24 [==============================] - 6s 229ms/step - loss: -0.5435 - dice_coef_labels: 0.5725 - dice_coef_myo: 0.5324 - dice_coef_lv: 0.5923 - dice_coef_rv: 0.5926 - val_loss: -0.2608 - val_dice_coef_labels: 0.3762 - val_dice_coef_myo: 0.2874 - val_dice_coef_lv: 0.5662 - val_dice_coef_rv: 0.3583
#
# Epoch 00014: loss improved from -0.44067 to -0.54350, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 15/150
# 24/24 [==============================] - 6s 232ms/step - loss: -0.6464 - dice_coef_labels: 0.6682 - dice_coef_myo: 0.6243 - dice_coef_lv: 0.6946 - dice_coef_rv: 0.6847 - val_loss: -0.1587 - val_dice_coef_labels: 0.3211 - val_dice_coef_myo: 0.2076 - val_dice_coef_lv: 0.4897 - val_dice_coef_rv: 0.3823
#
# Epoch 00015: loss improved from -0.54350 to -0.64639, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 16/150
# 24/24 [==============================] - 5s 229ms/step - loss: -0.7196 - dice_coef_labels: 0.7369 - dice_coef_myo: 0.6889 - dice_coef_lv: 0.7671 - dice_coef_rv: 0.7531 - val_loss: -0.4010 - val_dice_coef_labels: 0.4750 - val_dice_coef_myo: 0.3654 - val_dice_coef_lv: 0.6140 - val_dice_coef_rv: 0.4968
#
# Epoch 00016: loss improved from -0.64639 to -0.71962, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 17/150
# 24/24 [==============================] - 6s 230ms/step - loss: -0.7637 - dice_coef_labels: 0.7787 - dice_coef_myo: 0.7305 - dice_coef_lv: 0.8150 - dice_coef_rv: 0.7888 - val_loss: -0.4579 - val_dice_coef_labels: 0.5190 - val_dice_coef_myo: 0.3523 - val_dice_coef_lv: 0.7576 - val_dice_coef_rv: 0.5901
#
# Epoch 00017: loss improved from -0.71962 to -0.76369, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 18/150
# 24/24 [==============================] - 10s 418ms/step - loss: -0.7950 - dice_coef_labels: 0.8086 - dice_coef_myo: 0.7626 - dice_coef_lv: 0.8480 - dice_coef_rv: 0.8139 - val_loss: -0.6810 - val_dice_coef_labels: 0.7033 - val_dice_coef_myo: 0.5653 - val_dice_coef_lv: 0.8154 - val_dice_coef_rv: 0.7578
#
# Epoch 00018: loss improved from -0.76369 to -0.79496, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 19/150
# 24/24 [==============================] - 6s 231ms/step - loss: -0.8226 - dice_coef_labels: 0.8345 - dice_coef_myo: 0.7886 - dice_coef_lv: 0.8723 - dice_coef_rv: 0.8412 - val_loss: -0.8002 - val_dice_coef_labels: 0.8100 - val_dice_coef_myo: 0.7695 - val_dice_coef_lv: 0.8615 - val_dice_coef_rv: 0.8015
#
# Epoch 00019: loss improved from -0.79496 to -0.82259, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 20/150
# 24/24 [==============================] - 6s 230ms/step - loss: -0.8315 - dice_coef_labels: 0.8433 - dice_coef_myo: 0.7985 - dice_coef_lv: 0.8824 - dice_coef_rv: 0.8473 - val_loss: -0.7647 - val_dice_coef_labels: 0.7797 - val_dice_coef_myo: 0.7092 - val_dice_coef_lv: 0.8447 - val_dice_coef_rv: 0.7920
#
# Epoch 00020: loss improved from -0.82259 to -0.83154, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 21/150
# 24/24 [==============================] - 6s 239ms/step - loss: -0.8427 - dice_coef_labels: 0.8540 - dice_coef_myo: 0.8098 - dice_coef_lv: 0.8936 - dice_coef_rv: 0.8576 - val_loss: -0.7897 - val_dice_coef_labels: 0.8008 - val_dice_coef_myo: 0.7449 - val_dice_coef_lv: 0.8500 - val_dice_coef_rv: 0.8117
#
# Epoch 00021: loss improved from -0.83154 to -0.84267, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 22/150
# 24/24 [==============================] - 6s 233ms/step - loss: -0.8502 - dice_coef_labels: 0.8613 - dice_coef_myo: 0.8165 - dice_coef_lv: 0.9009 - dice_coef_rv: 0.8655 - val_loss: -0.6968 - val_dice_coef_labels: 0.7177 - val_dice_coef_myo: 0.5829 - val_dice_coef_lv: 0.8453 - val_dice_coef_rv: 0.7823
#
# Epoch 00022: loss improved from -0.84267 to -0.85020, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 23/150
# 24/24 [==============================] - 6s 230ms/step - loss: -0.8545 - dice_coef_labels: 0.8657 - dice_coef_myo: 0.8224 - dice_coef_lv: 0.9076 - dice_coef_rv: 0.8655 - val_loss: -0.6517 - val_dice_coef_labels: 0.6850 - val_dice_coef_myo: 0.5221 - val_dice_coef_lv: 0.7916 - val_dice_coef_rv: 0.8339
#
# Epoch 00023: loss improved from -0.85020 to -0.85454, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 24/150
# 24/24 [==============================] - 6s 231ms/step - loss: -0.8643 - dice_coef_labels: 0.8746 - dice_coef_myo: 0.8279 - dice_coef_lv: 0.9146 - dice_coef_rv: 0.8802 - val_loss: -0.8105 - val_dice_coef_labels: 0.8239 - val_dice_coef_myo: 0.7308 - val_dice_coef_lv: 0.9011 - val_dice_coef_rv: 0.8486
#
# Epoch 00024: loss improved from -0.85454 to -0.86432, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 25/150
# 24/24 [==============================] - 10s 416ms/step - loss: -0.8682 - dice_coef_labels: 0.8784 - dice_coef_myo: 0.8346 - dice_coef_lv: 0.9194 - dice_coef_rv: 0.8801 - val_loss: -0.8430 - val_dice_coef_labels: 0.8529 - val_dice_coef_myo: 0.8113 - val_dice_coef_lv: 0.9101 - val_dice_coef_rv: 0.8441
#
# Epoch 00025: loss improved from -0.86432 to -0.86815, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 26/150
# 24/24 [==============================] - 6s 234ms/step - loss: -0.8683 - dice_coef_labels: 0.8787 - dice_coef_myo: 0.8334 - dice_coef_lv: 0.9162 - dice_coef_rv: 0.8840 - val_loss: -0.8613 - val_dice_coef_labels: 0.8686 - val_dice_coef_myo: 0.8407 - val_dice_coef_lv: 0.9097 - val_dice_coef_rv: 0.8590
#
# Epoch 00026: loss improved from -0.86815 to -0.86831, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 27/150
# 24/24 [==============================] - 6s 236ms/step - loss: -0.8769 - dice_coef_labels: 0.8865 - dice_coef_myo: 0.8418 - dice_coef_lv: 0.9247 - dice_coef_rv: 0.8918 - val_loss: -0.8792 - val_dice_coef_labels: 0.8872 - val_dice_coef_myo: 0.8562 - val_dice_coef_lv: 0.9321 - val_dice_coef_rv: 0.8727
#
# Epoch 00027: loss improved from -0.86831 to -0.87689, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 28/150
# 24/24 [==============================] - 6s 234ms/step - loss: -0.8748 - dice_coef_labels: 0.8848 - dice_coef_myo: 0.8408 - dice_coef_lv: 0.9270 - dice_coef_rv: 0.8855 - val_loss: -0.8672 - val_dice_coef_labels: 0.8742 - val_dice_coef_myo: 0.8185 - val_dice_coef_lv: 0.9294 - val_dice_coef_rv: 0.8662
#
# Epoch 00028: loss did not improve from -0.87689
# Epoch 29/150
# 24/24 [==============================] - 10s 405ms/step - loss: -0.8780 - dice_coef_labels: 0.8878 - dice_coef_myo: 0.8421 - dice_coef_lv: 0.9282 - dice_coef_rv: 0.8918 - val_loss: -0.8637 - val_dice_coef_labels: 0.8721 - val_dice_coef_myo: 0.8416 - val_dice_coef_lv: 0.9162 - val_dice_coef_rv: 0.8601
#
# Epoch 00029: loss improved from -0.87689 to -0.87802, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 30/150
# 24/24 [==============================] - 6s 240ms/step - loss: -0.8787 - dice_coef_labels: 0.8885 - dice_coef_myo: 0.8453 - dice_coef_lv: 0.9294 - dice_coef_rv: 0.8899 - val_loss: -0.8281 - val_dice_coef_labels: 0.8398 - val_dice_coef_myo: 0.8274 - val_dice_coef_lv: 0.9036 - val_dice_coef_rv: 0.7907
#
# Epoch 00030: loss improved from -0.87802 to -0.87873, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 31/150
# 24/24 [==============================] - 6s 236ms/step - loss: -0.8766 - dice_coef_labels: 0.8867 - dice_coef_myo: 0.8453 - dice_coef_lv: 0.9294 - dice_coef_rv: 0.8843 - val_loss: -0.8524 - val_dice_coef_labels: 0.8634 - val_dice_coef_myo: 0.8497 - val_dice_coef_lv: 0.9133 - val_dice_coef_rv: 0.8297
#
# Epoch 00031: loss did not improve from -0.87873
# Epoch 32/150
# 24/24 [==============================] - 13s 542ms/step - loss: -0.8837 - dice_coef_labels: 0.8931 - dice_coef_myo: 0.8489 - dice_coef_lv: 0.9315 - dice_coef_rv: 0.8976 - val_loss: -0.8444 - val_dice_coef_labels: 0.8590 - val_dice_coef_myo: 0.7794 - val_dice_coef_lv: 0.8939 - val_dice_coef_rv: 0.9052
#
# Epoch 00032: loss improved from -0.87873 to -0.88373, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 33/150
# 24/24 [==============================] - 6s 234ms/step - loss: -0.8848 - dice_coef_labels: 0.8941 - dice_coef_myo: 0.8506 - dice_coef_lv: 0.9346 - dice_coef_rv: 0.8960 - val_loss: -0.8685 - val_dice_coef_labels: 0.8774 - val_dice_coef_myo: 0.8455 - val_dice_coef_lv: 0.9184 - val_dice_coef_rv: 0.8694
#
# Epoch 00033: loss improved from -0.88373 to -0.88476, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 34/150
# 24/24 [==============================] - 6s 233ms/step - loss: -0.8859 - dice_coef_labels: 0.8954 - dice_coef_myo: 0.8542 - dice_coef_lv: 0.9353 - dice_coef_rv: 0.8953 - val_loss: -0.8862 - val_dice_coef_labels: 0.8942 - val_dice_coef_myo: 0.8610 - val_dice_coef_lv: 0.9383 - val_dice_coef_rv: 0.8866
#
# Epoch 00034: loss improved from -0.88476 to -0.88590, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 35/150
# 24/24 [==============================] - 6s 234ms/step - loss: -0.8907 - dice_coef_labels: 0.8996 - dice_coef_myo: 0.8551 - dice_coef_lv: 0.9358 - dice_coef_rv: 0.9064 - val_loss: -0.8836 - val_dice_coef_labels: 0.8918 - val_dice_coef_myo: 0.8608 - val_dice_coef_lv: 0.9302 - val_dice_coef_rv: 0.8850
#
# Epoch 00035: loss improved from -0.88590 to -0.89068, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 36/150
# 24/24 [==============================] - 5s 227ms/step - loss: -0.8923 - dice_coef_labels: 0.9012 - dice_coef_myo: 0.8586 - dice_coef_lv: 0.9395 - dice_coef_rv: 0.9040 - val_loss: -0.8735 - val_dice_coef_labels: 0.8837 - val_dice_coef_myo: 0.8538 - val_dice_coef_lv: 0.9249 - val_dice_coef_rv: 0.8725
#
# Epoch 00036: loss improved from -0.89068 to -0.89229, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 37/150
# 24/24 [==============================] - 6s 232ms/step - loss: -0.8931 - dice_coef_labels: 0.9019 - dice_coef_myo: 0.8609 - dice_coef_lv: 0.9391 - dice_coef_rv: 0.9043 - val_loss: -0.8889 - val_dice_coef_labels: 0.8964 - val_dice_coef_myo: 0.8617 - val_dice_coef_lv: 0.9320 - val_dice_coef_rv: 0.8937
#
# Epoch 00037: loss improved from -0.89229 to -0.89311, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 38/150
# 24/24 [==============================] - 6s 238ms/step - loss: -0.8941 - dice_coef_labels: 0.9028 - dice_coef_myo: 0.8610 - dice_coef_lv: 0.9391 - dice_coef_rv: 0.9072 - val_loss: -0.8742 - val_dice_coef_labels: 0.8824 - val_dice_coef_myo: 0.8571 - val_dice_coef_lv: 0.9221 - val_dice_coef_rv: 0.8702
#
# Epoch 00038: loss improved from -0.89311 to -0.89413, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 39/150
# 24/24 [==============================] - 10s 401ms/step - loss: -0.8948 - dice_coef_labels: 0.9035 - dice_coef_myo: 0.8625 - dice_coef_lv: 0.9419 - dice_coef_rv: 0.9053 - val_loss: -0.8879 - val_dice_coef_labels: 0.8960 - val_dice_coef_myo: 0.8744 - val_dice_coef_lv: 0.9463 - val_dice_coef_rv: 0.8665
#
# Epoch 00039: loss improved from -0.89413 to -0.89483, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 40/150
# 24/24 [==============================] - 6s 235ms/step - loss: -0.8954 - dice_coef_labels: 0.9041 - dice_coef_myo: 0.8626 - dice_coef_lv: 0.9415 - dice_coef_rv: 0.9065 - val_loss: -0.8848 - val_dice_coef_labels: 0.8936 - val_dice_coef_myo: 0.8659 - val_dice_coef_lv: 0.9370 - val_dice_coef_rv: 0.8774
#
# Epoch 00040: loss improved from -0.89483 to -0.89545, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 41/150
# 24/24 [==============================] - 6s 235ms/step - loss: -0.8956 - dice_coef_labels: 0.9043 - dice_coef_myo: 0.8646 - dice_coef_lv: 0.9431 - dice_coef_rv: 0.9045 - val_loss: -0.8818 - val_dice_coef_labels: 0.8908 - val_dice_coef_myo: 0.8623 - val_dice_coef_lv: 0.9404 - val_dice_coef_rv: 0.8724
#
# Epoch 00041: loss improved from -0.89545 to -0.89558, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 42/150
# 24/24 [==============================] - 6s 240ms/step - loss: -0.8970 - dice_coef_labels: 0.9056 - dice_coef_myo: 0.8651 - dice_coef_lv: 0.9431 - dice_coef_rv: 0.9076 - val_loss: -0.8888 - val_dice_coef_labels: 0.8966 - val_dice_coef_myo: 0.8679 - val_dice_coef_lv: 0.9358 - val_dice_coef_rv: 0.8878
#
# Epoch 00042: loss improved from -0.89558 to -0.89698, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 43/150
# 24/24 [==============================] - 6s 236ms/step - loss: -0.8994 - dice_coef_labels: 0.9077 - dice_coef_myo: 0.8647 - dice_coef_lv: 0.9435 - dice_coef_rv: 0.9135 - val_loss: -0.8951 - val_dice_coef_labels: 0.9028 - val_dice_coef_myo: 0.8710 - val_dice_coef_lv: 0.9442 - val_dice_coef_rv: 0.8930
#
# Epoch 00043: loss improved from -0.89698 to -0.89936, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 44/150
# 24/24 [==============================] - 6s 229ms/step - loss: -0.8984 - dice_coef_labels: 0.9069 - dice_coef_myo: 0.8674 - dice_coef_lv: 0.9437 - dice_coef_rv: 0.9087 - val_loss: -0.9038 - val_dice_coef_labels: 0.9109 - val_dice_coef_myo: 0.8793 - val_dice_coef_lv: 0.9456 - val_dice_coef_rv: 0.9080
#
# Epoch 00044: loss did not improve from -0.89936
# Epoch 45/150
# 24/24 [==============================] - 9s 359ms/step - loss: -0.9007 - dice_coef_labels: 0.9088 - dice_coef_myo: 0.8669 - dice_coef_lv: 0.9439 - dice_coef_rv: 0.9140 - val_loss: -0.8905 - val_dice_coef_labels: 0.8989 - val_dice_coef_myo: 0.8742 - val_dice_coef_lv: 0.9354 - val_dice_coef_rv: 0.8899
#
# Epoch 00045: loss improved from -0.89936 to -0.90067, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 46/150
# 24/24 [==============================] - 10s 417ms/step - loss: -0.9007 - dice_coef_labels: 0.9090 - dice_coef_myo: 0.8695 - dice_coef_lv: 0.9464 - dice_coef_rv: 0.9097 - val_loss: -0.8860 - val_dice_coef_labels: 0.8944 - val_dice_coef_myo: 0.8686 - val_dice_coef_lv: 0.9333 - val_dice_coef_rv: 0.8824
#
# Epoch 00046: loss improved from -0.90067 to -0.90072, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 47/150
# 24/24 [==============================] - 6s 235ms/step - loss: -0.8998 - dice_coef_labels: 0.9082 - dice_coef_myo: 0.8678 - dice_coef_lv: 0.9437 - dice_coef_rv: 0.9121 - val_loss: -0.9010 - val_dice_coef_labels: 0.9083 - val_dice_coef_myo: 0.8799 - val_dice_coef_lv: 0.9394 - val_dice_coef_rv: 0.9063
#
# Epoch 00047: loss did not improve from -0.90072
# Epoch 48/150
# 24/24 [==============================] - 9s 365ms/step - loss: -0.9008 - dice_coef_labels: 0.9091 - dice_coef_myo: 0.8686 - dice_coef_lv: 0.9449 - dice_coef_rv: 0.9123 - val_loss: -0.8888 - val_dice_coef_labels: 0.8967 - val_dice_coef_myo: 0.8778 - val_dice_coef_lv: 0.9360 - val_dice_coef_rv: 0.8794
#
# Epoch 00048: loss improved from -0.90072 to -0.90078, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 49/150
# 24/24 [==============================] - 6s 243ms/step - loss: -0.9011 - dice_coef_labels: 0.9093 - dice_coef_myo: 0.8674 - dice_coef_lv: 0.9455 - dice_coef_rv: 0.9136 - val_loss: -0.8852 - val_dice_coef_labels: 0.8945 - val_dice_coef_myo: 0.8657 - val_dice_coef_lv: 0.9426 - val_dice_coef_rv: 0.8720
#
# Epoch 00049: loss improved from -0.90078 to -0.90106, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 50/150
# 24/24 [==============================] - 6s 233ms/step - loss: -0.9003 - dice_coef_labels: 0.9086 - dice_coef_myo: 0.8702 - dice_coef_lv: 0.9448 - dice_coef_rv: 0.9102 - val_loss: -0.8826 - val_dice_coef_labels: 0.8924 - val_dice_coef_myo: 0.8500 - val_dice_coef_lv: 0.9350 - val_dice_coef_rv: 0.8940
#
# Epoch 00050: loss did not improve from -0.90106
# Epoch 51/150
# 24/24 [==============================] - 6s 230ms/step - loss: -0.9026 - dice_coef_labels: 0.9108 - dice_coef_myo: 0.8706 - dice_coef_lv: 0.9469 - dice_coef_rv: 0.9134 - val_loss: -0.8615 - val_dice_coef_labels: 0.8727 - val_dice_coef_myo: 0.8593 - val_dice_coef_lv: 0.9306 - val_dice_coef_rv: 0.8234
#
# Epoch 00051: loss improved from -0.90106 to -0.90256, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 52/150
# 24/24 [==============================] - 6s 239ms/step - loss: -0.9024 - dice_coef_labels: 0.9106 - dice_coef_myo: 0.8734 - dice_coef_lv: 0.9487 - dice_coef_rv: 0.9092 - val_loss: -0.9041 - val_dice_coef_labels: 0.9114 - val_dice_coef_myo: 0.8844 - val_dice_coef_lv: 0.9525 - val_dice_coef_rv: 0.8953
#
# Epoch 00052: loss did not improve from -0.90256
# Epoch 53/150
# 24/24 [==============================] - 12s 512ms/step - loss: -0.9068 - dice_coef_labels: 0.9144 - dice_coef_myo: 0.8713 - dice_coef_lv: 0.9488 - dice_coef_rv: 0.9218 - val_loss: -0.9051 - val_dice_coef_labels: 0.9123 - val_dice_coef_myo: 0.8769 - val_dice_coef_lv: 0.9542 - val_dice_coef_rv: 0.9094
#
# Epoch 00053: loss improved from -0.90256 to -0.90676, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 54/150
# 24/24 [==============================] - 6s 230ms/step - loss: -0.9062 - dice_coef_labels: 0.9140 - dice_coef_myo: 0.8737 - dice_coef_lv: 0.9493 - dice_coef_rv: 0.9180 - val_loss: -0.8994 - val_dice_coef_labels: 0.9074 - val_dice_coef_myo: 0.8706 - val_dice_coef_lv: 0.9399 - val_dice_coef_rv: 0.9113
#
# Epoch 00054: loss did not improve from -0.90676
# Epoch 55/150
# 24/24 [==============================] - 9s 366ms/step - loss: -0.9074 - dice_coef_labels: 0.9150 - dice_coef_myo: 0.8760 - dice_coef_lv: 0.9492 - dice_coef_rv: 0.9189 - val_loss: -0.8674 - val_dice_coef_labels: 0.8781 - val_dice_coef_myo: 0.8279 - val_dice_coef_lv: 0.9403 - val_dice_coef_rv: 0.8650
#
# Epoch 00055: loss improved from -0.90676 to -0.90735, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 56/150
# 24/24 [==============================] - 6s 232ms/step - loss: -0.9083 - dice_coef_labels: 0.9160 - dice_coef_myo: 0.8746 - dice_coef_lv: 0.9495 - dice_coef_rv: 0.9225 - val_loss: -0.8986 - val_dice_coef_labels: 0.9062 - val_dice_coef_myo: 0.8797 - val_dice_coef_lv: 0.9476 - val_dice_coef_rv: 0.8958
#
# Epoch 00056: loss improved from -0.90735 to -0.90829, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 57/150
# 24/24 [==============================] - 6s 232ms/step - loss: -0.9060 - dice_coef_labels: 0.9139 - dice_coef_myo: 0.8733 - dice_coef_lv: 0.9482 - dice_coef_rv: 0.9192 - val_loss: -0.9046 - val_dice_coef_labels: 0.9112 - val_dice_coef_myo: 0.8846 - val_dice_coef_lv: 0.9445 - val_dice_coef_rv: 0.9047
#
# Epoch 00057: loss did not improve from -0.90829
# Epoch 58/150
# 24/24 [==============================] - 8s 339ms/step - loss: -0.9071 - dice_coef_labels: 0.9150 - dice_coef_myo: 0.8752 - dice_coef_lv: 0.9488 - dice_coef_rv: 0.9194 - val_loss: -0.9011 - val_dice_coef_labels: 0.9088 - val_dice_coef_myo: 0.8827 - val_dice_coef_lv: 0.9464 - val_dice_coef_rv: 0.9015
#
# Epoch 00058: loss did not improve from -0.90829
# Epoch 59/150
# 24/24 [==============================] - 9s 359ms/step - loss: -0.9049 - dice_coef_labels: 0.9130 - dice_coef_myo: 0.8736 - dice_coef_lv: 0.9494 - dice_coef_rv: 0.9143 - val_loss: -0.8954 - val_dice_coef_labels: 0.9043 - val_dice_coef_myo: 0.8703 - val_dice_coef_lv: 0.9467 - val_dice_coef_rv: 0.8951
#
# Epoch 00059: loss did not improve from -0.90829
# Epoch 60/150
# 24/24 [==============================] - 13s 525ms/step - loss: -0.9087 - dice_coef_labels: 0.9163 - dice_coef_myo: 0.8764 - dice_coef_lv: 0.9505 - dice_coef_rv: 0.9202 - val_loss: -0.8709 - val_dice_coef_labels: 0.8826 - val_dice_coef_myo: 0.8138 - val_dice_coef_lv: 0.9411 - val_dice_coef_rv: 0.8927
#
# Epoch 00060: loss improved from -0.90829 to -0.90867, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 61/150
# 24/24 [==============================] - 6s 234ms/step - loss: -0.9111 - dice_coef_labels: 0.9184 - dice_coef_myo: 0.8784 - dice_coef_lv: 0.9519 - dice_coef_rv: 0.9236 - val_loss: -0.8952 - val_dice_coef_labels: 0.9031 - val_dice_coef_myo: 0.8580 - val_dice_coef_lv: 0.9444 - val_dice_coef_rv: 0.9036
#
# Epoch 00061: loss improved from -0.90867 to -0.91113, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 62/150
# 24/24 [==============================] - 6s 236ms/step - loss: -0.9121 - dice_coef_labels: 0.9193 - dice_coef_myo: 0.8784 - dice_coef_lv: 0.9527 - dice_coef_rv: 0.9253 - val_loss: -0.9043 - val_dice_coef_labels: 0.9113 - val_dice_coef_myo: 0.8950 - val_dice_coef_lv: 0.9521 - val_dice_coef_rv: 0.8898
#
# Epoch 00062: loss improved from -0.91113 to -0.91205, saving model to models/2D/close_gap2/acdc_plus2/2019-10-29_20_44_fold0/checkpoint.h5
# Epoch 63/150
# 24/24 [==============================] - 6s 236ms/step - loss: -0.9115 - dice_coef_labels: 0.9189 - dice_coef_myo: 0.8798 - dice_coef_lv: 0.9516 - dice_coef_rv: 0.9242 - val_loss: -0.9035 - val_dice_coef_labels: 0.9120 - val_dice_coef_myo: 0.8843 - val_dice_coef_lv: 0.9444 - val_dice_coef_rv: 0.9065
#
# Epoch 00063: loss did not improve from -0.91205
# 2019-10-29 20:54:43,987 INFO Fold: 0 finished - saving scores.
# Epoch 00063: early stopping
# 2019-10-29 20:54:44,995 INFO Training fold 0 done in 636.683 s
# 2019-10-29 20:54:45,298 INFO All folds are finished in 636.985 sec
