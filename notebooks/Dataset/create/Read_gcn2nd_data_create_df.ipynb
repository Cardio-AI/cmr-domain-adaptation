# %%
# define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.notebook_imports import *
from pyforest import *
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2


from src.utils.utils_io import Console_and_file_logger, ensure_dir
Console_and_file_logger('create_splitting_for_gcn2nd')
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/data/git/cardio
# 2020-07-20 11:02:00,735 INFO -------------------- Start --------------------
# 2020-07-20 11:02:00,736 INFO Working directory: /mnt/data/git/cardio.
# 2020-07-20 11:02:00,736 INFO Log file: ./logs/create_splitting_for_gcn2nd.log
# 2020-07-20 11:02:00,736 INFO Log level for console: INFO

# %%
# select folder with the images and masks
# choose the root folder before the gt/pred sub-folders
from ipyfilechooser import FileChooser
path_chooser = FileChooser(os.path.join(os.getcwd(),'data/raw/'), '')
display(path_chooser)
# Out:
# FileChooser(path='/mnt/data/git/cardio/data/raw', filename='', show_hidden='False')

# %%
# read the raw imported 4D files
images = sorted(glob.glob('{}/*clean.nrrd'.format(path_chooser.selected), recursive=True))
masks = sorted(glob.glob('{}/*mask.nrrd'.format(path_chooser.selected), recursive=True))
logging.info(len(images))
logging.info(len(masks))
# create a dataframe for images and masks
patients = [os.path.basename(f).split('0000-')[1].split('_')[0] for f in images]
df = pd.DataFrame({'patient':patients, 'x_path': images, 'y_path':masks})
df.head()
# Out:
# 2020-07-20 11:02:22,370 INFO 193
# 2020-07-20 11:02:22,370 INFO 193
#     patient                                             x_path  \
# 0  02Z1L14N  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 1  04NEJQUZ  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 2  0AE4R74L  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 3  1DRHF745  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 4  1FTR75DW  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
#
#                                               y_path
# 0  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 1  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 2  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 3  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...
# 4  /mnt/data/git/cardio/data/raw/gcn_05_2020_sax_...

# %%
os.path.dirname(os.path.normpath(path_chooser.selected))
# Out:
# '/mnt/data/git/cardio/data/raw/gcn_05_2020_sax_excl_ax_patients'

# %%
# Filter the image and mask volume by contoured time-steps
# create 4D data
from src.data.Dataset import create_4d_volumes_from_4d_files
import_path = path_chooser.selected
export_path = '{}/4D'.format(os.path.dirname(os.path.normpath(path_chooser.selected))) # reduce path length by one
ensure_dir(export_path)

# load the original 4D files, also with all timesteps (incl not contoured time steps)
#images = sorted(glob.glob('/mnt/data/git/cardio/data/raw/gcn_05_2020/SAx/*clean.nrrd', recursive=True))
#masks = sorted(glob.glob('/mnt/data/git/cardio/data/raw/gcn_05_2020/SAx/*mask.nrrd', recursive=True))
logging.info(len(images))
logging.info(len(masks))
# create a dataframe for images and masks
patients = [os.path.basename(f).split('0000-')[1].split('_')[0] for f in images]
df = pd.DataFrame({'patient':patients, 'x_path': images, 'y_path':masks})

assert(len(df['x_path']) == len(df['y_path']))
logging.info('create 4D volumes from: {} with: {} files'.format(import_path, len(df['x_path'])))

# slice all 4D volumes, copy metadata and save them
steps, shapes = zip(*[create_4d_volumes_from_4d_files(img_f, mask_f, export_path) for img_f, mask_f in zip(df['x_path'], df['y_path'])])

# overwrite the dataframe if all files are copied
images_filtered = sorted(glob.glob(os.path.join(export_path, '*img.nrrd')))
masks_filtered = sorted(glob.glob(os.path.join(export_path, '*msk.nrrd')))
assert(len(df['x_path'] == len(images_filtered)))
df['x_path'] = images_filtered
df['y_path'] = masks_filtered

# remember filtered timesteps
df['timesteps'] = steps
df['img_shape'] = shapes

# save dataframe to disk for later processing
df.to_csv('reports/'+ import_path.replace('/','_') + '4d_dataset.csv', index=False)
# save df to the directory above
df.to_csv(os.path.join(os.path.dirname(export_path), '4d_dataset.csv'), index=False)

# %%
df.head()
# Out:
#     patient                                             x_path  \
# 0  02Z1L14N  data/raw/gcn_05_2020/4D/0000-02Z1L14N_2006-11-...
# 1  04NEJQUZ  data/raw/gcn_05_2020/4D/0000-04NEJQUZ_2007-03-...
# 2  0AE4R74L  data/raw/gcn_05_2020/4D/0000-0AE4R74L_1900-01-...
# 3  0HQQW4ZN  data/raw/gcn_05_2020/4D/0000-0HQQW4ZN_2007-05-...
# 4  0PTV75MP  data/raw/gcn_05_2020/4D/0000-0PTV75MP_2005-06-...
#
#                                               y_path            timesteps  \
# 0  data/raw/gcn_05_2020/4D/0000-02Z1L14N_2006-11-...    [2, 5, 7, 11, 13]
# 1  data/raw/gcn_05_2020/4D/0000-04NEJQUZ_2007-03-...  [5, 12, 16, 20, 23]
# 2  data/raw/gcn_05_2020/4D/0000-0AE4R74L_1900-01-...    [1, 3, 6, 10, 12]
# 3  data/raw/gcn_05_2020/4D/0000-0HQQW4ZN_2007-05-...  [6, 10, 15, 21, 24]
# 4  data/raw/gcn_05_2020/4D/0000-0PTV75MP_2005-06-...    [0, 3, 7, 11, 13]
#
#            img_shape
# 0  (5, 10, 192, 138)
# 1  (5, 16, 256, 256)
# 2  (5, 11, 192, 144)
# 3  (5, 10, 256, 256)
# 4  (5, 12, 256, 256)

# %%
# create 3D data
from src.data.Dataset import create_3d_volumes_from_4d_files
import_path = path_chooser.selected
export_path = '{}/3D'.format(os.path.dirname(os.path.normpath(path_chooser.selected))) # reduce path length by one
ensure_dir(export_path)

# load the original 4D files, also with all timesteps (incl not contoured time steps)
logging.info(len(images))
logging.info(len(masks))
# create a dataframe for images and masks
patients = [os.path.basename(f).split('0000-')[1].split('_')[0] for f in images]
df = pd.DataFrame({'patient':patients, 'x_path': images, 'y_path':masks})

assert(len(images) == len(masks))
logging.info('create 3D volumes from: {} with: {} files'.format(import_path, len(images)))

# slice all 4D volumes, copy metadata and save them
steps, shapes = zip(*[create_3d_volumes_from_4d_files(img_f, mask_f, export_path) for img_f, mask_f in zip(images, masks)])

# overwrite the dataframe if all files are copied
images_filtered = sorted(glob.glob(os.path.join(export_path, '*img.nrrd')))
masks_filtered = sorted(glob.glob(os.path.join(export_path, '*msk.nrrd')))
patients = [f.split('/')[-1].split('_')[0] for f in images_filtered]
df = pd.DataFrame({'patient': patients, 'x_path':images_filtered, 'y_path': masks_filtered})

# save dataframe to disk for later processing
df.to_csv('reports/'+ import_path.replace('/','_') + '3d_dataset.csv')

# save df to the directory above
df.to_csv(os.path.join(os.path.dirname(export_path), '3d_dataset.csv'), index=False)

# %%
# create 2D data from 4D raw volumes
only_masked = True
from src.data.Dataset import create_2d_slices_from_4d_volume_files
import_path = path_chooser.selected
export_path = '{}/2D'.format(os.path.dirname(os.path.normpath(path_chooser.selected))) # reduce path length by one
ensure_dir(export_path)

# load the original 4D files, also with all timesteps (incl not contoured time steps)
logging.info(len(images))
logging.info(len(masks))
# create a dataframe for images and masks
patients = [os.path.basename(f).split('0000-')[1].split('_')[0] for f in images]
df = pd.DataFrame({'patient':patients, 'x_path': images, 'y_path':masks})

assert(len(images) == len(masks))
logging.info('create 2D slices from: {} with: {} files'.format(import_path, len(images)))

# slice all 4D volumes, copy metadata and save them
steps, shapes = zip(*[create_2d_slices_from_4d_volume_files(img_f, mask_f, export_path, only_masked) for img_f, mask_f in zip(images, masks)])

# overwrite the dataframe if all files are copied
images_filtered = sorted(glob.glob(os.path.join(export_path, '*img.nrrd')))
masks_filtered = sorted(glob.glob(os.path.join(export_path, '*msk.nrrd')))
patients = [f.split('/')[-1].split('_')[0] for f in images_filtered]
df = pd.DataFrame({'patient': patients, 'x_path':images_filtered, 'y_path': masks_filtered})

# save dataframe to disk for later processing
df.to_csv('reports/'+ import_path.replace('/','_') + '2d_dataset.csv', index=False)

# save df to the directory above
df.to_csv(os.path.join(os.path.dirname(export_path), '2d_dataset.csv'), index=False)

# %%
# add phase info to 3d dataframe
df = pd.read_csv('data/raw/gcn_05_2020/3d_dataset.csv')
df.shape
# Out:
# (1393, 3)

# %%
df_meta = pd.read_excel('data/raw/miccai2020/M&Ms Dataset Information.xlsx')
df.shape
# Out:
# (300, 3)

# %%
df_meta.head()
# Out:
#   External code Vendor  Centre  ED  ES
# 0        A0S9V9      A       1   0   9
# 1        A1D0Q7      B       2   0   9
# 2        A1D9Z7      A       1  22  11
# 3        A1E9Q1      A       1   0   9
# 4        A1O8Z3      B       3  23  10

# %%
#map one row
temp  = df.iloc[0]
temp
# Out:
# patient                                               A0S9V9
# x_path     data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# y_path     data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...
# Name: 0, dtype: object

# %%
# get the metadata for this row
df_temp = df_meta[df_meta['External code']==temp['patient']]
df_temp
# Out:
#   External code Vendor  Centre  ED  ES
# 0        A0S9V9      A       1   0   9

# %%
def map_row_with_meta(row):
    """
    Helper to map the phase, vencor, centre from the metadata csv
    additionally extract the t and z position from the filename
    """
    phase = 'ES'
    timestep = os.path.basename(row['x_path']).split('_t')[1].split('_')[0]
    df_temp = df_meta[df_meta['External code']==row['patient']]
    # change phase according to the timestep
    if int(df_temp['ED']) == int(timestep):
        phase = 'ED'
    z_pos = 0
    # extract the z-position if this is a 2D filename
    if '_z' in os.path.basename(row.x_path):
        f = os.path.basename(row.x_path)
        z_pos = f.split('_')[-2][1:]
    return str(phase), int(timestep), int(z_pos), str(df_temp['Vendor'].values[0]), int(df_temp['Centre'])

# %%
df['Phase'],df['T'], df['Z'], df['Vendor'], df['Centre'] = zip(*df.apply(map_row_with_meta, axis=1))

# %%
df.head()
# Out:
#   patient                                             x_path  \
# 0  A0S9V9  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 1  A0S9V9  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_i...
# 2  A1D0Q7  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t0_i...
# 3  A1D0Q7  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t9_i...
# 4  A1D9Z7  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t11_...
#
#                                               y_path Phase   T  Z Vendor  \
# 0  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...    ED   0  0      A
# 1  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_m...    ES   9  0      A
# 2  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t0_m...    ED   0  0      B
# 3  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t9_m...    ES   9  0      B
# 4  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t11_...    ES  11  0      A
#
#    Centre
# 0       1
# 1       1
# 2       2
# 3       2
# 4       1

# %%
# save extended dataframe
df.to_csv('data/raw/miccai2020/3d_dataset.csv', index=False)

# %%
# extend the 2D dataframe with the metadata
df = pd.read_csv('data/raw/miccai2020/2d_dataset.csv')
df.head()
# Out:
#   patient                                             x_path  \
# 0  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 1  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 2  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 3  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 4  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
#
#                                               y_path
# 0  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 1  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 2  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 3  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 4  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...

# %%
df['Phase'],df['T'], df['Z'], df['Vendor'], df['Centre'] = zip(*df.apply(map_row_with_meta, axis=1))

# %%
df = df.sort_values(['patient', 'T', 'Z'])

# %%
# save extended dataframe
df.to_csv('data/raw/miccai2020/2d_dataset.csv', index=False)

# %% [markdown]
# # Create folds for crossvalidation

# %%
# 3D
df = pd.read_csv('data/raw/gcn_05_2020/SAx 2D_dataset.csv')
print(df.shape)
df.head()
# Out:
# (300, 8)
#   patient                                             x_path  \
# 0  A0S9V9  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 1  A0S9V9  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_i...
# 2  A1D0Q7  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t0_i...
# 3  A1D0Q7  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t9_i...
# 4  A1D9Z7  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t11_...
#
#                                               y_path Phase   T  Z Vendor  \
# 0  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...    ED   0  0      A
# 1  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_m...    ES   9  0      A
# 2  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t0_m...    ED   0  0      B
# 3  data/raw/miccai2020/3D_filtered/A1D0Q7_sa_t9_m...    ES   9  0      B
# 4  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t11_...    ES  11  0      A
#
#    Centre
# 0       1
# 1       1
# 2       2
# 3       2
# 4       1

# %%
from src.data.Dataset import get_kfolded_data
Console_and_file_logger('Test')
# Out:
# 2020-05-26 17:26:28,933 INFO -------------------- Start --------------------
# 2020-05-26 17:26:28,934 INFO Working directory: /mnt/data/git/cardio.
# 2020-05-26 17:26:28,934 INFO Log file: ./logs/Test.log
# 2020-05-26 17:26:28,935 INFO Log level for console: INFO

# %%
def get_patient(file_name):
    """Helper assume a filename: patientid_sa_t_z.img.nrrd"""
    return os.path.basename(file_name).split('_')[0]

# %%
# create a patient based splitting
df_ = get_kfolded_data(kfolds=4,path_to_data='data/raw/miccai2020/3D_filtered/',extract_patient_id=get_patient)
# Out:
# 2020-05-26 17:26:29,004 INFO found: 300 files
# 2020-05-26 17:26:29,008 INFO found: 150 patients

# %%
print(df_.shape)
df_.head()
# Out:
# (1200, 5)
#   fold                                             x_path  \
# 0    3  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 1    3  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_i...
# 2    3  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t11_...
# 3    3  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t22_...
# 4    3  data/raw/miccai2020/3D_filtered/A1E9Q1_sa_t0_i...
#
#                                               y_path modality patient
# 0  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...    train  A0S9V9
# 1  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_m...    train  A0S9V9
# 2  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t11_...    train  A1D9Z7
# 3  data/raw/miccai2020/3D_filtered/A1D9Z7_sa_t22_...    train  A1D9Z7
# 4  data/raw/miccai2020/3D_filtered/A1E9Q1_sa_t0_m...    train  A1E9Q1

# %%
def extract_t_z_from_x_path(row):
    """
    Helper to map the phase, vencor, centre from the metadata csv
    additionally extract the t and z position from the filename
    """
    timestep = os.path.basename(row['x_path']).split('_t')[1].split('_')[0]
    z_pos = 0
    # extract the z-position if this is a 2D filename
    if '_z' in os.path.basename(row.x_path):
        f = os.path.basename(row.x_path)
        z_pos = f.split('_')[-2][1:]
    return int(timestep), int(z_pos)

# %%
df_['T'], df_['Z'] = zip(*df_.apply(extract_t_z_from_x_path, axis=1))

# %%
df_merge = pd.merge(df[['patient', 'T', 'Z', 'Phase', 'Vendor', 'Centre']], df_, how='right', right_on=['patient', 'T', 'Z'], left_on=['patient', 'T', 'Z'])
df_merge.head()
# Out:
#   patient  T  Z Phase Vendor  Centre fold  \
# 0  A0S9V9  0  0    ED      A       1    3
# 1  A0S9V9  0  0    ED      A       1    2
# 2  A0S9V9  0  0    ED      A       1    1
# 3  A0S9V9  0  0    ED      A       1    0
# 4  A0S9V9  9  0    ES      A       1    3
#
#                                               x_path  \
# 0  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 1  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 2  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 3  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_i...
# 4  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_i...
#
#                                               y_path modality
# 0  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...    train
# 1  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...    train
# 2  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...     test
# 3  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t0_m...    train
# 4  data/raw/miccai2020/3D_filtered/A0S9V9_sa_t9_m...    train

# %%
df_merge.to_csv('data/raw/miccai2020/3d_dataset.csv', index=False)

# %%
# 2D 
df = pd.read_csv('data/raw/miccai2020/2d_dataset.csv')
print(df.shape)
df.head()
# Out:
# (3284, 8)
#   patient                                             x_path  \
# 0  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 1  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 2  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 3  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 4  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
#
#                                               y_path Phase  T  Z Vendor  \
# 0  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  0      A
# 1  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  1      A
# 2  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  2      A
# 3  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  3      A
# 4  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  4      A
#
#    Centre
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# reuse the splitting from our 3D dataframe (df_)
folds = []
for i in range(4):
    temp = df.copy()
    temp['fold'] = i
    folds.append(temp)
df_folds = pd.concat(folds)
print(df_folds.shape)
df_folds.head()
# Out:
# (13136, 9)
#   patient                                             x_path  \
# 0  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 1  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 2  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 3  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 4  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
#
#                                               y_path Phase  T  Z Vendor  \
# 0  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  0      A
# 1  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  1      A
# 2  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  2      A
# 3  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  3      A
# 4  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  4      A
#
#    Centre  fold
# 0       1     0
# 1       1     0
# 2       1     0
# 3       1     0
# 4       1     0

# %%
df_folds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13136 entries, 0 to 3283
# Data columns (total 9 columns):
# patient    13136 non-null object
# x_path     13136 non-null object
# y_path     13136 non-null object
# Phase      13136 non-null object
# T          13136 non-null int64
# Z          13136 non-null int64
# Vendor     13136 non-null object
# Centre     13136 non-null int64
# fold       13136 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 1.0+ MB

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 75
# Data columns (total 7 columns):
# fold        1200 non-null object
# x_path      1200 non-null object
# y_path      1200 non-null object
# modality    1200 non-null object
# patient     1200 non-null object
# T           1200 non-null int64
# Z           1200 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 75.0+ KB

# %%
df_merge = df_folds.merge(df_[['patient', 'fold','T', 'modality']], how='left', on=['patient','T','fold'])
print(df_merge.shape)
df_merge.head()
# Out:
# (13136, 10)
#   patient                                             x_path  \
# 0  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 1  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 2  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 3  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
# 4  A0S9V9  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...
#
#                                               y_path Phase  T  Z Vendor  \
# 0  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  0      A
# 1  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  1      A
# 2  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  2      A
# 3  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  3      A
# 4  data/raw/miccai2020/2D_filtered/A0S9V9_sa_t0_z...    ED  0  4      A
#
#    Centre fold modality
# 0       1    0    train
# 1       1    0    train
# 2       1    0    train
# 3       1    0    train
# 4       1    0    train

# %%
df_merge.to_csv('data/raw/miccai2020/2d_dataset.csv', index=False)
